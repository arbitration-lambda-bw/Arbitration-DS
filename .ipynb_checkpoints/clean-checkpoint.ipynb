# %%
import csv
import os
import random

# %%
import pandas as pd

# %%
import numpy as np
import datetime

# %%
opp_files = os.listdir('../opp_data')
opp_csvs = []
for f in opp_files:
    if f.endswith('.csv'):
        opp_csvs.append(f)

# %%
sorted(opp_csvs)[:10]
# Out:
# ['ar_little_rock_2019_02_25.csv',
#  'az_gilbert_2019_02_25.csv',
#  'az_mesa_2019_02_25.csv',
#  'az_statewide_2019_02_25.csv',
#  'ca_anaheim_2019_02_25.csv',
#  'ca_bakersfield_2019_02_25.csv',
#  'ca_long_beach_2019_02_26.csv',
#  'ca_san_bernardino_2019_02_25.csv',
#  'ca_san_diego_2019_02_25.csv',
#  'ca_san_francisco_2019_02_25.csv']

# %%
with open(str('../opp_data/' + opp_csvs[0]), 'rt') as csvf:
    r = csv.reader(csvf)
    row1 = next(r)
row1
# Out:
# ['raw_row_number',
#  'date',
#  'time',
#  'zone',
#  'subject_race',
#  'subject_sex',
#  'department_id',
#  'type',
#  'arrest_made',
#  'citation_issued',
#  'warning_issued',
#  'outcome',
#  'contraband_found',
#  'contraband_drugs',
#  'contraband_weapons',
#  'contraband_alcohol',
#  'contraband_other',
#  'frisk_performed',
#  'search_conducted',
#  'search_basis',
#  'reason_for_search',
#  'reason_for_stop',
#  'vehicle_make',
#  'vehicle_model']

# %%
yield

# %%
def get_n_rows(file, n_rows):
    with open(file, 'rt') as csvf:
        r = csv.reader(csvf)
        headers = next(r)
        data = []
        row_count = sum(1 for row in r)
        rrows = [random.randint(1,row_count) for i in range(n_rows)].sort()
    with open(file, 'rt') as csvf:
        r = csv.reader(csvf)
        next(r)
        for i in range(n_rows):
            data.append(next(r))
    return(headers, data)

# %%
h, d = get_n_rows(str('../opp_data/' + opp_csvs[0]), 100)

# %%
h
# Out:
# ['raw_row_number',
#  'date',
#  'time',
#  'zone',
#  'subject_race',
#  'subject_sex',
#  'department_id',
#  'type',
#  'arrest_made',
#  'citation_issued',
#  'warning_issued',
#  'outcome',
#  'contraband_found',
#  'contraband_drugs',
#  'contraband_weapons',
#  'contraband_alcohol',
#  'contraband_other',
#  'frisk_performed',
#  'search_conducted',
#  'search_basis',
#  'reason_for_search',
#  'reason_for_stop',
#  'vehicle_make',
#  'vehicle_model']

# %%
d
# Out:
# [['1',
#   '2005-11-22',
#   '11:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['2',
#   '2005-10-01',
#   '12:20:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['3',
#   '2005-10-01',
#   '12:30:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['4',
#   '2005-10-01',
#   '12:50:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['5',
#   '2005-10-01',
#   '13:10:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['6',
#   '2005-10-01',
#   '15:50:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['7',
#   '2005-09-11',
#   '11:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['8',
#   '2005-09-11',
#   '11:45:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['9',
#   '2005-10-04',
#   '11:55:00',
#   'X3',
#   'hispanic',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['10',
#   '2005-10-04',
#   '11:55:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['11',
#   '2005-10-04',
#   '14:28:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['12',
#   '2005-10-04',
#   '14:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['13',
#   '2005-10-04',
#   '15:02:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['14',
#   '2005-10-04',
#   '15:35:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['15',
#   '2005-10-10',
#   '17:50:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['16',
#   '2005-10-10',
#   '18:10:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['17',
#   '2005-10-10',
#   '18:35:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['18',
#   '2005-10-10',
#   '19:20:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['19',
#   '2005-10-17',
#   '11:55:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['20',
#   '2005-10-17',
#   '14:10:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['21',
#   '2005-10-17',
#   '14:40:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['22',
#   '2005-10-17',
#   '14:50:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['23',
#   '2005-10-18',
#   '09:20:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['24',
#   '2005-10-23',
#   '18:10:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['25',
#   '2005-10-23',
#   '18:40:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['26',
#   '2005-12-15',
#   '13:20:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['27',
#   '2005-12-15',
#   '15:10:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Equipment/Inspection Violation',
#   'NA',
#   'NA'],
#  ['28',
#   '2005-12-15',
#   '15:50:00',
#   'X3',
#   'hispanic',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['29',
#   '2005-12-15',
#   '17:05:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['30',
#   '2005-12-16',
#   '08:25:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['31',
#   '2005-12-16',
#   '11:40:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['32',
#   '2005-12-17',
#   '11:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['33',
#   '2005-12-17',
#   '11:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['34',
#   '2005-12-17',
#   '12:00:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['35',
#   '2005-12-17',
#   '12:00:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['36',
#   '2005-12-17',
#   '14:00:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['37',
#   '2005-10-06',
#   '10:40:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['38',
#   '2005-10-06',
#   '12:35:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['39',
#   '2005-10-06',
#   '12:55:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['40',
#   '2005-10-06',
#   '12:55:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['41',
#   '2005-10-06',
#   '15:10:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['42',
#   '2005-10-22',
#   '08:48:00',
#   'X3',
#   'black',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['43',
#   '2005-10-22',
#   '09:00:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['44',
#   '2005-10-22',
#   '11:25:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['45',
#   '2005-10-22',
#   '14:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['46',
#   '2005-10-22',
#   '14:30:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['47',
#   '2005-10-23',
#   '18:40:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['48',
#   '2005-10-24',
#   '08:50:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['49',
#   '2005-10-24',
#   '09:35:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['50',
#   '2005-10-24',
#   '10:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['51',
#   '2005-10-24',
#   '12:55:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['52',
#   '2005-10-24',
#   '14:55:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['53',
#   '2005-10-24',
#   '14:55:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['54',
#   '2005-10-24',
#   '14:55:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['55',
#   '2005-11-02',
#   '20:55:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['56',
#   '2005-11-03',
#   '09:40:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['57',
#   '2005-11-03',
#   '10:10:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Equipment/Inspection Violation',
#   'NA',
#   'NA'],
#  ['58',
#   '2005-11-03',
#   '10:33:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Equipment/Inspection Violation',
#   'NA',
#   'NA'],
#  ['59',
#   '2005-11-03',
#   '12:00:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Equipment/Inspection Violation',
#   'NA',
#   'NA'],
#  ['60',
#   '2005-11-03',
#   '20:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['61',
#   '2005-11-04',
#   '12:30:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['62',
#   '2005-11-04',
#   '14:25:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['63',
#   '2005-11-04',
#   '14:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['64',
#   '2005-11-04',
#   '15:00:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['65',
#   '2005-11-04',
#   '15:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['66',
#   '2005-11-04',
#   '15:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['67',
#   '2005-11-09',
#   '08:45:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['68',
#   '2005-11-09',
#   '08:45:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['69',
#   '2005-11-09',
#   '14:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['70',
#   '2005-11-09',
#   '14:37:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['71',
#   '2005-11-09',
#   '15:05:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['72',
#   '2005-11-10',
#   '11:00:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['73',
#   '2005-11-10',
#   '11:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['74',
#   '2005-11-10',
#   '19:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['75',
#   '2005-11-10',
#   '20:15:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['76',
#   '2005-11-11',
#   '09:00:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['77',
#   '2005-11-11',
#   '10:30:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['78',
#   '2005-11-11',
#   '11:20:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['79',
#   '2005-11-11',
#   '13:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['80',
#   '2005-11-11',
#   '13:55:00',
#   'X3',
#   'black',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['81',
#   '2005-11-11',
#   '14:58:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['82',
#   '2005-11-11',
#   '15:20:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['83',
#   '2005-11-11',
#   '15:20:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['84',
#   '2005-11-11',
#   '16:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['85',
#   '2005-11-15',
#   '08:05:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['86',
#   '2005-11-15',
#   '10:25:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['87',
#   '2005-11-15',
#   '10:55:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['88',
#   '2005-11-15',
#   '11:10:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['89',
#   '2005-11-15',
#   '11:10:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['90',
#   '2005-11-15',
#   '11:55:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['91',
#   '2005-11-15',
#   '13:45:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['92',
#   '2005-11-15',
#   '14:15:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['93',
#   '2005-11-15',
#   '14:40:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['94',
#   '2005-11-15',
#   '15:25:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['95',
#   '2005-11-15',
#   '16:12:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['96',
#   '2005-11-17',
#   '08:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['97',
#   '2005-11-17',
#   '09:45:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['98',
#   '2005-11-17',
#   '10:20:00',
#   'X3',
#   'white',
#   'male',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Speeding',
#   'NA',
#   'NA'],
#  ['99',
#   '2005-11-17',
#   '10:55:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA'],
#  ['100',
#   '2005-11-17',
#   '19:45:00',
#   'X3',
#   'white',
#   'female',
#   '200',
#   'vehicular',
#   'FALSE',
#   'TRUE',
#   'FALSE',
#   'citation',
#   'NA',
#   'NA',
#   'NA',
#   'NA',
#   'FALSE',
#   'FALSE',
#   'FALSE',
#   'NA',
#   'NA',
#   'Other Traffic Violation',
#   'NA',
#   'NA']]

# %%
def nrows_to_df(file, n_rows):
    rt = sum(1 for lin in open(file, 'rt'))
    skip = sorted(random.sample(range(1,rt+1), rt - n_rows))
    df = pd.read_csv(file, skiprows = skip)
    return(df)

# %%
states = []
for f in opp_csvs:
    if f[:2] not in states:
        states.append(f[:2])

# %%
len(states)
# Out:
# 42

# %%
print(sorted(states))
# Out:
# ['ar', 'az', 'ca', 'co', 'ct', 'fl', 'ga', 'ia', 'id', 'il', 'in', 'ks', 'ky', 'la', 'ma', 'md', 'mi', 'mn', 'mo', 'ms', 'mt', 'nc', 'nd', 'ne', 'nh', 'nj', 'nv', 'ny', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx', 'va', 'vt', 'wa', 'wi', 'wy']

# %%
names = []
for f in sorted(opp_csvs):
    fs = f.split('_')
    name = str(fs[0] + '_' + fs[1])
    names.append(name)
print(names)
# Out:
# ['ar_little', 'az_gilbert', 'az_mesa', 'az_statewide', 'ca_anaheim', 'ca_bakersfield', 'ca_long', 'ca_san', 'ca_san', 'ca_san', 'ca_san', 'ca_santa', 'ca_statewide', 'ca_stockton', 'co_aurora', 'co_denver', 'co_statewide', 'ct_hartford', 'ct_statewide', 'fl_saint', 'fl_statewide', 'fl_tampa', 'ga_statewide', 'ia_statewide', 'id_idaho', 'il_chicago', 'il_statewide', 'in_fort', 'ks_wichita', 'ky_owensboro', 'la_new', 'ma_statewide', 'md_baltimore', 'md_statewide', 'mi_statewide', 'mn_saint', 'mo_statewide', 'ms_statewide', 'mt_statewide', 'nc_charlotte', 'nc_durham', 'nc_fayetteville', 'nc_greensboro', 'nc_raleigh', 'nc_statewide', 'nc_winston-salem', 'nd_grand', 'nd_statewide', 'ne_statewide', 'nh_statewide', 'nj_camden', 'nj_statewide', 'nv_statewide', 'ny_albany', 'ny_statewide', 'oh_cincinnati', 'oh_columbus', 'oh_statewide', 'ok_oklahoma', 'ok_tulsa', 'or_statewide', 'pa_philadelphia', 'ri_statewide', 'sc_statewide', 'sd_statewide', 'tn_statewide', 'tx_arlington', 'tx_austin', 'tx_houston', 'tx_san', 'tx_statewide', 'va_statewide', 'vt_burlington', 'vt_statewide', 'wa_seattle', 'wa_statewide', 'wa_tacoma', 'wi_madison', 'wi_statewide', 'wy_statewide']

# %%
dfs = {}
for file in sorted(opp_csvs):
    name = str(file.split('_')[0] + '_' + file.split('_')[1])
    dfs[str(name)] = nrows_to_df(file=str('../opp_data/' + file), n_rows=1000)

# %%
dfs['ar_little'].head()
# Out:
#    raw_row_number        date      time  lat  lng  subject_age  \
# 0               1  2017-10-19  15:17:37 -inf -inf         33.0
# 1              31  2017-09-10  10:34:26 -inf -inf         66.0
# 2              46  2017-07-19  02:41:07 -inf -inf         26.0
# 3              52  2017-08-28  09:10:25 -inf -inf         56.0
# 4             167  2017-05-20  17:22:47 -inf -inf         48.0
#
#              subject_race subject_sex       type  citation_issued   outcome  \
# 0                   black      female  vehicular             True  citation
# 1  asian/pacific islander        male  vehicular             True  citation
# 2                   white        male  vehicular             True  citation
# 3                   black        male  vehicular             True  citation
# 4                   black        male  vehicular             True  citation
#
#     vehicle_type
# 0  Passenger Car
# 1  Passenger Car
# 2  Passenger Car
# 3  Passenger Car
# 4  Passenger Car

# %%
dfs['wy_statewide'].head()
# Out:
#    raw_row_number        date      time                           location  \
# 0             418  2011-01-03  16:40:00         68 85|68 85, GOSHEN COUNTY
# 1             476  2011-01-03  21:01:00          321 I 80 W, ALBANY COUNTY
# 2             647  2011-01-04  18:40:00            72 191, SUBLETTE COUNTY
# 3            1308  2011-01-07  21:31:00               4 14, BIGHORN COUNTY
# 4            1377  2011-01-08  11:00:00  52 30|58 30|52 30, LINCOLN COUNTY
#
#        county_name  subject_age subject_race subject_sex officer_id_hash  \
# 0    Goshen County         31.0        white        male      f9345ff1ac
# 1    Albany County         53.0        white        male      c39b7673a4
# 2  Sublette County         29.0        white        male      091f9c87a8
# 3   Bighorn County         19.0        white      female      f53b537376
# 4   Lincoln County         59.0        white        male      a9b26cfd94
#
#   department_id       type                                          violation
# 0             F  vehicular  EXCEED 75 MPH ON INTERSTATE (SPEED)|DRIVE WHIL...
# 1             J  vehicular         EXCEED POSTED SPEED IN SUPERINTENDENT ZONE
# 2             T  vehicular          EXCEED 65 MPH ON PRMRY/SCNDRY HWY (SPEED)
# 3             N  vehicular                           NO VALID DRIVERS LICENSE
# 4             D  vehicular  LEAKING, SPILLING, BLOWING, FALLING CARGO|FAIL...

# %%
len(dfs.keys())
# Out:
# 77

# %%
dfs.keys()
# Out:
# dict_keys(['ar_little', 'az_gilbert', 'az_mesa', 'az_statewide', 'ca_anaheim', 'ca_bakersfield', 'ca_long', 'ca_san', 'ca_santa', 'ca_statewide', 'ca_stockton', 'co_aurora', 'co_denver', 'co_statewide', 'ct_hartford', 'ct_statewide', 'fl_saint', 'fl_statewide', 'fl_tampa', 'ga_statewide', 'ia_statewide', 'id_idaho', 'il_chicago', 'il_statewide', 'in_fort', 'ks_wichita', 'ky_owensboro', 'la_new', 'ma_statewide', 'md_baltimore', 'md_statewide', 'mi_statewide', 'mn_saint', 'mo_statewide', 'ms_statewide', 'mt_statewide', 'nc_charlotte', 'nc_durham', 'nc_fayetteville', 'nc_greensboro', 'nc_raleigh', 'nc_statewide', 'nc_winston-salem', 'nd_grand', 'nd_statewide', 'ne_statewide', 'nh_statewide', 'nj_camden', 'nj_statewide', 'nv_statewide', 'ny_albany', 'ny_statewide', 'oh_cincinnati', 'oh_columbus', 'oh_statewide', 'ok_oklahoma', 'ok_tulsa', 'or_statewide', 'pa_philadelphia', 'ri_statewide', 'sc_statewide', 'sd_statewide', 'tn_statewide', 'tx_arlington', 'tx_austin', 'tx_houston', 'tx_san', 'tx_statewide', 'va_statewide', 'vt_burlington', 'vt_statewide', 'wa_seattle', 'wa_statewide', 'wa_tacoma', 'wi_madison', 'wi_statewide', 'wy_statewide'])

# %%
for name in names:
    if name not in dfs.keys():
        print(name)

# %%
len(dfs.keys())
# Out:
# 77

# %%
dfs['ca_san'].shape
# Out:
# (1000, 16)

# %%
for key in dfs.keys():
    cols = dfs[key].columns
    print(str('\n' + '****'*40 + '\n' ))
    print('\n', str('---'*10 + '  '*5 + '<<  ' + key + '  >>' + '  '*5 + '---'*10))
    for col in dfs[key].columns:
        info = [col, type(dfs[key][col].values[0])]
        print(info, end='  ')
    print(str('\n' + '****'*40 + '\n' ))
# Out:
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ar_little  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['vehicle_type', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  az_gilbert  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['vehicle_color', <class 'float'>]  ['vehicle_make', <class 'float'>]  ['vehicle_model', <class 'numpy.float64'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  az_mesa  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  az_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'float'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'float'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_other', <class 'numpy.bool_'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'float'>]  ['vehicle_type', <class 'str'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_anaheim  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['type', <class 'str'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_bakersfield  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['beat', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_long  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['beat', <class 'numpy.float64'>]  ['district', <class 'numpy.float64'>]  ['subdistrict', <class 'numpy.float64'>]  ['division', <class 'str'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['officer_age', <class 'numpy.int64'>]  ['officer_race', <class 'str'>]  ['officer_sex', <class 'str'>]  ['officer_years_of_service', <class 'numpy.int64'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['vehicle_make', <class 'float'>]  ['vehicle_registration_state', <class 'float'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_san  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'float'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['outcome', <class 'float'>]  ['contraband_found', <class 'float'>]  ['search_conducted', <class 'bool'>]  ['reason_for_stop', <class 'str'>]  ['use_of_force_description', <class 'str'>]  ['use_of_force_reason', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_santa  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'numpy.float64'>]  ['region', <class 'str'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['county_name', <class 'str'>]  ['district', <class 'str'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'float'>]  ['citation_issued', <class 'float'>]  ['warning_issued', <class 'float'>]  ['outcome', <class 'float'>]  ['contraband_found', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_stockton  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['division', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'float'>]  ['type', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]  ['search_conducted', <class 'bool'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  co_aurora  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'numpy.float64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  co_denver  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'str'>]  ['precinct', <class 'str'>]  ['type', <class 'str'>]  ['disposition', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'float'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  co_statewide  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'numpy.float64'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['officer_sex', <class 'float'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_basis', <class 'float'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ct_hartford  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'str'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_vehicle', <class 'numpy.bool_'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ct_statewide  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_vehicle', <class 'numpy.bool_'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  fl_saint  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'numpy.float64'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  fl_statewide  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'float'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['officer_age', <class 'numpy.float64'>]  ['officer_race', <class 'str'>]  ['officer_sex', <class 'str'>]  ['officer_years_of_service', <class 'numpy.float64'>]  ['department_name', <class 'str'>]  ['unit', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]  ['frisk_performed', <class 'bool'>]  ['search_conducted', <class 'bool'>]  ['search_basis', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['vehicle_registration_state', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  fl_tampa  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['vehicle_registration_state', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ga_statewide  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'float'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['county_name', <class 'str'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['outcome', <class 'str'>]  ['vehicle_color', <class 'str'>]  ['vehicle_make', <class 'str'>]  ['vehicle_model', <class 'float'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ia_statewide  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'float'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'float'>]  ['subject_sex', <class 'float'>]  ['officer_id_hash', <class 'float'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]  ['vehicle_color', <class 'float'>]  ['vehicle_make', <class 'float'>]  ['vehicle_model', <class 'float'>]  ['vehicle_registration_state', <class 'float'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  id_idaho  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['neighborhood', <class 'str'>]  ['division', <class 'str'>]  ['subdivision', <class 'numpy.int64'>]  ['zone', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['disposition', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  il_chicago  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'float'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'float'>]  ['officer_age', <class 'numpy.float64'>]  ['officer_race', <class 'float'>]  ['officer_sex', <class 'float'>]  ['officer_years_of_service', <class 'numpy.float64'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'float'>]  ['outcome', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  il_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'numpy.float64'>]  ['beat', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_id', <class 'numpy.int64'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['search_conducted', <class 'bool'>]  ['search_person', <class 'numpy.bool_'>]  ['search_vehicle', <class 'bool'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]  ['vehicle_make', <class 'str'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  in_fort  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['type', <class 'str'>]  ['disposition', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ks_wichita  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['disposition', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['posted_speed', <class 'numpy.float64'>]  ['vehicle_color', <class 'str'>]  ['vehicle_make', <class 'str'>]  ['vehicle_model', <class 'float'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ky_owensboro  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['sector', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['reason_for_stop', <class 'str'>]  ['vehicle_registration_state', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  la_new  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'float'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'numpy.int64'>]  ['zone', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_assignment', <class 'str'>]  ['type', <class 'float'>]  ['arrest_made', <class 'float'>]  ['citation_issued', <class 'float'>]  ['warning_issued', <class 'float'>]  ['outcome', <class 'float'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'float'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]  ['vehicle_color', <class 'float'>]  ['vehicle_make', <class 'float'>]  ['vehicle_model', <class 'float'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ma_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['contraband_alcohol', <class 'numpy.bool_'>]  ['contraband_other', <class 'numpy.bool_'>]  ['frisk_performed', <class 'numpy.bool_'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]  ['vehicle_type', <class 'str'>]  ['vehicle_registration_state', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  md_baltimore  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['beat', <class 'str'>]  ['district', <class 'numpy.float64'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'float'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  md_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'float'>]  ['location', <class 'float'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['disposition', <class 'float'>]  ['violation', <class 'float'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_arrest', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  mi_statewide  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_race', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_id', <class 'numpy.int64'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  mn_saint  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['police_grid_number', <class 'numpy.int64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['frisk_performed', <class 'bool'>]  ['search_conducted', <class 'bool'>]  ['search_vehicle', <class 'bool'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  mo_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['location', <class 'str'>]  ['subject_race', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['contraband_found', <class 'bool'>]  ['search_conducted', <class 'numpy.bool_'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ms_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_id', <class 'numpy.int64'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  mt_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]  ['vehicle_make', <class 'str'>]  ['vehicle_model', <class 'str'>]  ['vehicle_type', <class 'float'>]  ['vehicle_registration_state', <class 'str'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nc_charlotte  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'float'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_frisk', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nc_durham  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'float'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_frisk', <class 'numpy.float64'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nc_fayetteville  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_frisk', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nc_greensboro  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'float'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_frisk', <class 'numpy.float64'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nc_raleigh  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_frisk', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nc_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'float'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_frisk', <class 'numpy.float64'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nc_winston-salem  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['frisk_performed', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_person', <class 'float'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['reason_for_frisk', <class 'numpy.float64'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nd_grand  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'float'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  nd_statewide  >>          ------------------------------
# ['raw_row_number', <class 'str'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.int64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ne_statewide  >>          ------------------------------
# ...
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  tx_houston  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['beat', <class 'str'>]  ['district', <class 'numpy.float64'>]  ['subject_race', <class 'float'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['speed', <class 'numpy.int64'>]  ['posted_speed', <class 'numpy.int64'>]  ['vehicle_color', <class 'str'>]  ['vehicle_make', <class 'str'>]  ['vehicle_model', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  tx_san  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'numpy.float64'>]  ['substation', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'float'>]  ['citation_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_basis', <class 'float'>]  ['reason_for_stop', <class 'str'>]  ['speed', <class 'numpy.int64'>]  ['posted_speed', <class 'numpy.int64'>]  ['vehicle_color', <class 'float'>]  ['vehicle_make', <class 'float'>]  ['vehicle_model', <class 'float'>]  ['vehicle_registration_state', <class 'float'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  tx_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['county_name', <class 'str'>]  ['district', <class 'str'>]  ['precinct', <class 'numpy.float64'>]  ['region', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['search_conducted', <class 'bool'>]  ['search_vehicle', <class 'float'>]  ['search_basis', <class 'float'>]  ['vehicle_color', <class 'float'>]  ['vehicle_make', <class 'float'>]  ['vehicle_model', <class 'float'>]  ['vehicle_type', <class 'str'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  va_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_race', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['officer_race', <class 'numpy.float64'>]  ['type', <class 'str'>]  ['search_conducted', <class 'numpy.bool_'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  vt_burlington  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['search_conducted', <class 'bool'>]  ['search_basis', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]  ['vehicle_registration_state', <class 'float'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  vt_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'bool'>]  ['warning_issued', <class 'bool'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['search_conducted', <class 'bool'>]  ['search_basis', <class 'float'>]  ['reason_for_search', <class 'float'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  wa_seattle  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['beat', <class 'str'>]  ['precinct', <class 'str'>]  ['sector', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'numpy.float64'>]  ['subject_sex', <class 'numpy.float64'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['reason_for_stop', <class 'str'>]  ['vehicle_color', <class 'float'>]  ['vehicle_make', <class 'float'>]  ['vehicle_model', <class 'float'>]  ['vehicle_registration_state', <class 'float'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  wa_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_race', <class 'str'>]  ['officer_sex', <class 'str'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'float'>]  ['arrest_made', <class 'bool'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['frisk_performed', <class 'bool'>]  ['search_conducted', <class 'bool'>]  ['search_basis', <class 'float'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  wa_tacoma  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['sector', <class 'numpy.float64'>]  ['subsector', <class 'numpy.float64'>]  ['officer_id_hash', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['reason_for_stop', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  wi_madison  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'numpy.float64'>]  ['sector', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['speed', <class 'numpy.float64'>]  ['posted_speed', <class 'numpy.float64'>]  ['vehicle_color', <class 'str'>]  ['vehicle_make', <class 'str'>]  ['vehicle_model', <class 'float'>]  ['vehicle_registration_state', <class 'str'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  wi_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['county_name', <class 'str'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['department_id', <class 'numpy.int64'>]  ['department_name', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'float'>]  ['contraband_drugs', <class 'float'>]  ['contraband_weapons', <class 'float'>]  ['contraband_alcohol', <class 'float'>]  ['contraband_other', <class 'float'>]  ['search_conducted', <class 'bool'>]  ['search_person', <class 'bool'>]  ['search_vehicle', <class 'numpy.bool_'>]  ['search_basis', <class 'float'>]  ['vehicle_color', <class 'str'>]  ['vehicle_make', <class 'str'>]  ['vehicle_model', <class 'str'>]  ['vehicle_type', <class 'str'>]  ['vehicle_registration_state', <class 'str'>]  ['vehicle_year', <class 'numpy.float64'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  wy_statewide  >>          ------------------------------
# ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['county_name', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['officer_id_hash', <class 'str'>]  ['department_id', <class 'str'>]  ['type', <class 'str'>]  ['violation', <class 'str'>]
# ****************************************************************************************************************************************************************
#
#
# ****************************************************************************************************************************************************************
#
#
#  ------------------------------          <<  ca_sanfran  >>          ------------------------------
# ['Unnamed: 0', <class 'numpy.int64'>]  ['raw_row_number', <class 'numpy.int64'>]  ['date', <class 'str'>]  ['time', <class 'str'>]  ['location', <class 'str'>]  ['lat', <class 'numpy.float64'>]  ['lng', <class 'numpy.float64'>]  ['district', <class 'str'>]  ['subject_age', <class 'numpy.float64'>]  ['subject_race', <class 'str'>]  ['subject_sex', <class 'str'>]  ['type', <class 'str'>]  ['arrest_made', <class 'numpy.bool_'>]  ['citation_issued', <class 'numpy.bool_'>]  ['warning_issued', <class 'numpy.bool_'>]  ['outcome', <class 'str'>]  ['contraband_found', <class 'numpy.bool_'>]  ['search_conducted', <class 'numpy.bool_'>]  ['search_vehicle', <class 'numpy.bool_'>]  ['search_basis', <class 'str'>]  ['reason_for_stop', <class 'str'>]  ['hour', <class 'numpy.int64'>]
# ****************************************************************************************************************************************************************

# %%
sanfran = nrows_to_df('../opp_data/sanfran.csv', 1000)

# %%
for key in dfs.keys():
    print(key)
    print(dfs[key].isnull().sum())
    print('\n\n')
# Out:
# ar_little
# raw_row_number     0
# date               0
# time               0
# lat                0
# lng                0
# subject_age        3
# subject_race       0
# subject_sex        2
# type               0
# citation_issued    0
# outcome            0
# vehicle_type       0
# dtype: int64
#
#
#
# az_gilbert
# raw_row_number        0
# date                  0
# time                  0
# location              0
# lat                   1
# lng                   1
# officer_id_hash       0
# type                  0
# vehicle_color       999
# vehicle_make        999
# vehicle_model      1000
# vehicle_year       1000
# dtype: int64
#
#
#
# az_mesa
# raw_row_number      0
# date                0
# time                4
# location            6
# lat                16
# lng                16
# subject_age        12
# subject_race        0
# subject_sex        13
# officer_id_hash     0
# type               71
# violation           0
# arrest_made         0
# citation_issued     0
# warning_issued      0
# outcome             0
# dtype: int64
#
#
#
# az_statewide
# raw_row_number        0
# date                  0
# time                  0
# location              0
# county_name         110
# subject_race          0
# subject_sex           0
# officer_id_hash       0
# type                  0
# violation           477
# arrest_made           0
# citation_issued       0
# warning_issued        0
# outcome             107
# contraband_found    951
# contraband_drugs    951
# contraband_other      0
# search_conducted      0
# search_person       972
# search_vehicle      951
# search_basis        951
# reason_for_stop      50
# vehicle_type          9
# vehicle_year          9
# dtype: int64
#
#
#
# ca_anaheim
# raw_row_number     0
# date               0
# type               0
# reason_for_stop    0
# dtype: int64
#
#
#
# ca_bakersfield
# raw_row_number      0
# date                0
# time                6
# location            1
# lat                13
# lng                13
# beat               76
# subject_age         6
# subject_race        6
# subject_sex         7
# officer_id_hash     0
# type                0
# citation_issued     0
# outcome             0
# dtype: int64
#
#
#
# ca_long
# raw_row_number                  0
# date                            0
# location                        0
# lat                           249
# lng                           249
# beat                          332
# district                      332
# subdistrict                   332
# division                      332
# subject_age                     0
# subject_race                    0
# subject_sex                     0
# officer_id_hash                 0
# officer_age                     0
# officer_race                    0
# officer_sex                     0
# officer_years_of_service        0
# type                            0
# violation                       0
# citation_issued                 0
# outcome                         0
# vehicle_make                  147
# vehicle_registration_state    156
# vehicle_year                  150
# dtype: int64
#
#
#
# ca_san
# raw_row_number                0
# date                          0
# time                          0
# location                     70
# lat                         102
# lng                         102
# subject_race                 45
# type                        123
# arrest_made                   1
# citation_issued               1
# outcome                     614
# contraband_found            744
# search_conducted             66
# reason_for_stop              61
# use_of_force_description    136
# use_of_force_reason          85
# dtype: int64
#
#
#
# ca_santa
# raw_row_number      0
# date                0
# location            0
# lat                 1
# lng                 1
# district           41
# region             35
# subject_race        4
# subject_sex         0
# officer_id_hash     0
# type                1
# violation           0
# citation_issued     0
# outcome             0
# dtype: int64
#
#
#
# ca_statewide
# raw_row_number         0
# date                   0
# county_name            3
# district               3
# subject_race           0
# subject_sex            0
# department_name        0
# type                   0
# violation              0
# arrest_made          297
# citation_issued      297
# warning_issued       297
# outcome              297
# contraband_found     999
# frisk_performed      998
# search_conducted       0
# search_person        998
# search_basis         964
# reason_for_search    964
# reason_for_stop        0
# dtype: int64
#
#
#
# ca_stockton
# raw_row_number        0
# date                  0
# division              0
# subject_age           2
# subject_race          1
# subject_sex           1
# officer_id_hash     450
# type                  0
# arrest_made           1
# citation_issued       1
# warning_issued        1
# outcome               1
# search_conducted      2
# search_basis        868
# reason_for_stop       1
# dtype: int64
#
#
#
# co_aurora
# raw_row_number       0
# date                 0
# time                 3
# location             0
# lat                171
# lng                171
# district           180
# subject_age         35
# subject_race         0
# subject_sex         12
# type                26
# violation           21
# citation_issued      0
# outcome              0
# dtype: int64
#
#
#
# co_denver
# raw_row_number       0
# date                 0
# time                 0
# location             0
# lat                  0
# lng                  0
# district             0
# precinct             0
# type                 0
# disposition          0
# arrest_made          0
# citation_issued      0
# warning_issued       0
# outcome            525
# dtype: int64
#
#
#
# co_statewide
# raw_row_number         0
# date                   0
# time                1000
# location               0
# county_name            0
# subject_age          238
# subject_race         139
# subject_sex          232
# officer_id_hash      104
# officer_sex          656
# type                   0
# violation            163
# arrest_made          427
# citation_issued      427
# warning_issued       427
# outcome              561
# contraband_found     997
# search_conducted       0
# search_basis         997
# dtype: int64
#
#
#
# ct_hartford
# raw_row_number        0
# date                  0
# time                  0
# location              0
# lat                  12
# lng                  12
# district             60
# subject_age           0
# subject_race          0
# subject_sex           0
# officer_id_hash       0
# department_name       0
# type                  0
# arrest_made           0
# citation_issued       0
# warning_issued        0
# outcome             155
# contraband_found    718
# search_conducted      0
# search_vehicle        0
# search_basis        718
# reason_for_stop       0
# dtype: int64
#
#
#
# ct_statewide
# raw_row_number        0
# date                  0
# time                  0
# location              0
# lat                 776
# lng                 776
# county_name           0
# subject_age           1
# subject_race          0
# subject_sex           0
# officer_id_hash     123
# department_name       0
# type                 11
# violation             1
# arrest_made           0
# citation_issued       0
# warning_issued        0
# outcome              15
# contraband_found    966
# search_conducted      0
# search_vehicle        0
# search_basis        969
# reason_for_stop     521
# dtype: int64
#
#
#
# fl_saint
# raw_row_number      0
# date                0
# time                0
# location            0
# lat                94
# lng                94
# district           18
# officer_id_hash     0
# type                0
# dtype: int64
#
#
#
# fl_statewide
# raw_row_number                  0
# date                            0
# time                            0
# location                      765
# county_name                     0
# subject_age                   249
# subject_race                    0
# subject_sex                   247
# officer_id_hash                 0
# officer_age                   203
# officer_race                  232
# officer_sex                   152
# officer_years_of_service       86
# department_name               246
# unit                            3
# type                            0
# violation                      86
# arrest_made                    86
# citation_issued                93
# warning_issued                268
# outcome                        21
# frisk_performed                86
# search_conducted               87
# search_basis                  996
# reason_for_search             998
# vehicle_registration_state    249
# dtype: int64
#
#
#
# fl_tampa
# raw_row_number                 0
# date                           0
# subject_age                    0
# subject_race                  24
# subject_sex                    0
# department_name                0
# type                           0
# violation                      0
# citation_issued                0
# outcome                        0
# vehicle_registration_state    21
# dtype: int64
#
#
#
# ga_statewide
# raw_row_number       0
# date                 0
# time                 0
# location           676
# lat                  9
# lng                  9
# county_name          0
# subject_race       483
# subject_sex         44
# officer_id_hash      0
# department_name      0
# type                 0
# violation            0
# outcome              0
# vehicle_color       22
# vehicle_make        10
# vehicle_model       35
# vehicle_year        39
# dtype: int64
#
#
#
# ia_statewide
# raw_row_number                  0
# date                            0
# time                          158
# location                      112
# county_name                   958
# subject_age                   623
# subject_race                  757
# subject_sex                   623
# officer_id_hash               429
# department_name               409
# type                          156
# violation                      80
# citation_issued               162
# warning_issued                162
# outcome                       162
# vehicle_color                 472
# vehicle_make                  463
# vehicle_model                 489
# vehicle_registration_state    628
# vehicle_year                  634
# dtype: int64
#
#
#
# id_idaho
# raw_row_number       0
# date                 0
# time                 0
# location             0
# lat                164
# lng                164
# neighborhood        66
# division           387
# subdivision          0
# zone                75
# officer_id_hash      0
# type                 0
# disposition        689
# dtype: int64
#
#
#
# il_chicago
# raw_row_number                0
# date                          0
# time                          0
# location                     82
# lat                         244
# lng                         244
# subject_age                 762
# subject_race                749
# subject_sex                   0
# officer_id_hash             831
# officer_age                 940
# officer_race                 69
# officer_sex                  69
# officer_years_of_service     74
# type                          0
# violation                     0
# arrest_made                 762
# citation_issued             237
# outcome                       0
# dtype: int64
#
#
#
# il_statewide
# raw_row_number          0
# date                    0
# time                    0
# location               10
# beat                   17
# subject_age             1
# subject_race            0
# subject_sex             0
# department_id           0
# department_name         0
# type                    0
# violation               0
# citation_issued         0
# warning_issued          0
# outcome                 0
# contraband_found      826
# contraband_drugs      826
# contraband_weapons    826
# search_conducted        1
# search_person           0
# search_vehicle          1
# search_basis          857
# reason_for_stop         0
# vehicle_make           15
# vehicle_year            1
# dtype: int64
#
#
#
# in_fort
# raw_row_number       0
# date                 0
# time                 0
# location             0
# lat                 33
# lng                 33
# type                 0
# disposition          4
# arrest_made          4
# citation_issued      4
# warning_issued       4
# outcome            308
# dtype: int64
#
#
#
# ks_wichita
# raw_row_number       0
# date                 0
# time                 0
# location            28
# lat                 30
# lng                 30
# subject_age        187
# subject_race        20
# subject_sex        176
# type                 0
# disposition         21
# violation            0
# citation_issued      0
# outcome              0
# posted_speed       698
# vehicle_color       55
# vehicle_make        50
# vehicle_model      507
# vehicle_year       706
# dtype: int64
#
#
#
# ky_owensboro
# raw_row_number                0
# date                          0
# time                          0
# location                      1
# lat                           0
# lng                           1
# sector                        1
# subject_age                   0
# subject_race                  3
# subject_sex                   0
# officer_id_hash               0
# type                          5
# arrest_made                   0
# citation_issued               0
# outcome                       0
# reason_for_stop               2
# vehicle_registration_state    3
# dtype: int64
#
#
#
# la_new
# raw_row_number          0
# date                    0
# time                    0
# location              195
# lat                   489
# lng                   489
# district                0
# zone                    0
# subject_age            23
# subject_race           20
# subject_sex            20
# officer_assignment      0
# type                  298
# arrest_made           255
# citation_issued       255
# warning_issued        255
# outcome               355
# contraband_found      857
# contraband_drugs      857
# contraband_weapons    857
# frisk_performed       255
# search_conducted      255
# search_person         255
# search_vehicle        255
# search_basis          857
# reason_for_stop         0
# vehicle_color         478
# vehicle_make          474
# vehicle_model         505
# vehicle_year          482
# dtype: int64
#
#
#
# ma_statewide
# raw_row_number                  0
# date                            0
# location                        0
# county_name                     0
# subject_age                    47
# subject_race                    0
# subject_sex                     8
# type                            0
# arrest_made                     0
# citation_issued                 0
# warning_issued                  0
# outcome                         1
# contraband_found              981
# contraband_drugs              981
# contraband_weapons            981
# contraband_alcohol              0
# contraband_other                0
# frisk_performed                 0
# search_conducted                0
# search_basis                  982
# reason_for_stop               445
# vehicle_type                    4
# vehicle_registration_state      2
# dtype: int64
#
#
#
# md_baltimore
# raw_row_number       0
# date                 0
# time                11
# beat               361
# district           398
# officer_id_hash     88
# type                26
# citation_issued      0
# outcome              0
# dtype: int64
#
#
#
# md_statewide
# raw_row_number          0
# date                   24
# time                  795
# location              795
# subject_age           796
# subject_race            2
# subject_sex            12
# department_name         0
# type                    0
# disposition           981
# violation             998
# arrest_made            59
# citation_issued        67
# warning_issued         67
# outcome               220
# contraband_found      978
# contraband_drugs      978
# contraband_weapons    978
# search_conducted        0
# search_person         977
# search_vehicle        977
# search_basis          998
# reason_for_arrest     986
# reason_for_search     977
# reason_for_stop        10
# dtype: int64
#
#
#
# mi_statewide
# raw_row_number      0
# date                0
# time                0
# location            0
# county_name         0
# subject_race       27
# officer_id_hash     0
# department_id       0
# department_name     0
# type                0
# violation           0
# arrest_made         0
# citation_issued     0
# warning_issued      0
# outcome             0
# reason_for_stop     0
# dtype: int64
#
#
#
# mn_saint
# raw_row_number          0
# date                    0
# time                    0
# lat                     0
# lng                     0
# police_grid_number      0
# subject_age           859
# subject_race          180
# subject_sex           169
# type                    0
# citation_issued         0
# outcome               854
# frisk_performed       164
# search_conducted      165
# search_vehicle        165
# dtype: int64
#
#
#
# mo_statewide
# raw_row_number        0
# date                  0
# location              0
# subject_race          0
# department_name       0
# type                  0
# contraband_found    928
# search_conducted      0
# dtype: int64
#
#
#
# ms_statewide
# raw_row_number      0
# date                0
# county_name         6
# subject_age         0
# subject_race        0
# subject_sex         0
# department_id       0
# department_name    10
# type                0
# violation           0
# dtype: int64
#
#
#
# mt_statewide
# raw_row_number                  0
# date                            0
# time                            0
# location                        3
# lat                             0
# lng                             0
# county_name                     0
# subject_age                     3
# subject_race                    0
# subject_sex                     0
# department_name                 0
# type                            0
# violation                       0
# arrest_made                     0
# citation_issued                 0
# warning_issued                  0
# outcome                         2
# search_conducted                0
# search_basis                  995
# reason_for_stop                 0
# vehicle_make                    5
# vehicle_model                  26
# vehicle_type                   74
# vehicle_registration_state     52
# vehicle_year                   12
# dtype: int64
#
#
#
# nc_charlotte
# raw_row_number          0
# date                    0
# time                    1
# location                0
# county_name             1
# subject_age             0
# subject_race            0
# subject_sex             0
# officer_id_hash         0
# department_name         0
# type                    0
# arrest_made             0
# citation_issued         0
# warning_issued          0
# outcome                39
# contraband_found      952
# contraband_drugs      952
# contraband_weapons    952
# frisk_performed       952
# search_conducted        0
# search_person         952
# search_vehicle        952
# search_basis          953
# reason_for_frisk      999
# reason_for_search     952
# reason_for_stop         0
# dtype: int64
#
#
#
# nc_durham
# raw_row_number           0
# date                     0
# time                   164
# location                 0
# county_name              0
# subject_age              0
# subject_race             0
# subject_sex              0
# officer_id_hash          0
# department_name          0
# type                     0
# arrest_made              0
# citation_issued          0
# warning_issued           0
# outcome                 31
# contraband_found       933
# contraband_drugs       933
# contraband_weapons     933
# frisk_performed        933
# search_conducted         0
# search_person          933
# search_vehicle         933
# search_basis           933
# reason_for_frisk      1000
# reason_for_search      933
# reason_for_stop          0
# dtype: int64
#
#
#
# nc_fayetteville
# raw_row_number          0
# date                    0
# time                   34
# location                0
# county_name             0
# subject_age             0
# subject_race            0
# subject_sex             0
# officer_id_hash         0
# department_name         0
# type                    0
# arrest_made             0
# citation_issued         0
# warning_issued          0
# outcome                27
# contraband_found      948
# contraband_drugs      948
# contraband_weapons    948
# frisk_performed       948
# search_conducted        0
# search_person         948
# search_vehicle        948
# search_basis          952
# reason_for_frisk      996
# reason_for_search     948
# reason_for_stop         0
# dtype: int64
#
#
#
# nc_greensboro
# raw_row_number           0
# date                     0
# time                     6
# location                 0
# county_name              2
# subject_age              0
# subject_race             0
# subject_sex              0
# officer_id_hash          0
# department_name          0
# type                     0
# arrest_made              0
# citation_issued          0
# warning_issued           0
# outcome                 36
# contraband_found       950
# contraband_drugs       950
# contraband_weapons     950
# frisk_performed        950
# search_conducted         0
# search_person          950
# search_vehicle         950
# search_basis           950
# reason_for_frisk      1000
# reason_for_search      950
# reason_for_stop          0
# dtype: int64
#
#
#
# nc_raleigh
# raw_row_number          0
# date                    0
# time                    1
# location                0
# county_name             0
# subject_age             0
# subject_race            0
# subject_sex             0
# officer_id_hash         0
# department_name         0
# type                    0
# arrest_made             0
# citation_issued         0
# warning_issued          0
# outcome                20
# contraband_found      965
# contraband_drugs      965
# contraband_weapons    965
# frisk_performed       965
# search_conducted        0
# search_person         965
# search_vehicle        965
# search_basis          967
# reason_for_frisk      998
# reason_for_search     965
# reason_for_stop         0
# dtype: int64
#
#
#
# nc_statewide
# raw_row_number           0
# date                     0
# time                   509
# location                 4
# county_name             19
# subject_age              0
# subject_race             0
# subject_sex              0
# officer_id_hash          0
# department_name          0
# type                     0
# arrest_made              0
# citation_issued          0
# warning_issued           0
# outcome                 37
# contraband_found       973
# contraband_drugs       973
# contraband_weapons     973
# frisk_performed        973
# search_conducted         0
# search_person          973
# search_vehicle         973
# search_basis           973
# reason_for_frisk      1000
# reason_for_search      973
# reason_for_stop          0
# dtype: int64
#
#
#
# nc_winston-salem
# raw_row_number           0
# date                     0
# time                   226
# location                 0
# county_name              0
# subject_age              0
# subject_race             0
# subject_sex              0
# officer_id_hash          0
# department_name          0
# type                     0
# arrest_made              0
# citation_issued          0
# warning_issued           0
# outcome                 16
# contraband_found       976
# contraband_drugs       976
# contraband_weapons     976
# frisk_performed        976
# search_conducted         0
# search_person          976
# search_vehicle         976
# search_basis           976
# reason_for_frisk      1000
# reason_for_search      976
# reason_for_stop          0
# dtype: int64
#
#
#
# nd_grand
# raw_row_number       0
# date                 0
# time                 0
# location            37
# lat                 57
# lng                 57
# subject_race         9
# subject_sex          0
# type               391
# citation_issued      0
# warning_issued       0
# outcome              0
# reason_for_stop      0
# dtype: int64
#
#
#
# nd_statewide
# raw_row_number     0
# date               0
# time               0
# location           2
# county_name        0
# subject_age        0
# subject_race       0
# subject_sex        0
# type               3
# violation          0
# reason_for_stop    0
# dtype: int64
#
#
#
# ne_statewide
# raw_row_number        0
# date                  0
# location            517
# subject_race          0
# department_name       0
# type                  0
# search_conducted      0
# dtype: int64
#
#
#
# nh_statewide
# raw_row_number       0
# date                 0
# time                 0
# location             0
# lat                109
# lng                109
# county_name          0
# subject_age        475
# subject_race       345
# subject_sex         14
# type                 0
# violation           53
# citation_issued      0
# warning_issued       0
# outcome             51
# dtype: int64
#
#
#
# nj_camden
# raw_row_number                  0
# date                            0
# time                            0
# location                       13
# lat                            21
# lng                            21
# subject_age                    12
# subject_race                    9
# subject_sex                     1
# unit                          559
# type                            0
# disposition                     0
# arrest_made                     0
# citation_issued                 0
# warning_issued                  0
# outcome                       547
# vehicle_color                 295
# vehicle_make                  296
# vehicle_model                 301
# vehicle_registration_state    269
# vehicle_year                  304
# dtype: int64
#
#
#
# nj_statewide
# raw_row_number                  0
# date                            0
# time                            0
# location                        0
# subject_race                   25
# subject_sex                     4
# officer_id_hash                 0
# department_id                   0
# type                            0
# violation                     254
# arrest_made                   974
# citation_issued               239
# warning_issued                241
# outcome                       238
# frisk_performed               973
# search_conducted              972
# vehicle_color                  21
# vehicle_make                   42
# vehicle_model                 749
# vehicle_registration_state      6
# dtype: int64
#
#
#
# nv_statewide
# raw_row_number      0
# date                0
# subject_age        76
# subject_race        1
# type                0
# violation           0
# arrest_made         0
# citation_issued     0
# warning_issued      0
# outcome             0
# dtype: int64
#
#
#
# ny_albany
# raw_row_number                  0
# date                            0
# time                            0
# location                      110
# lat                           111
# lng                           111
# subject_age                     0
# subject_race                  399
# subject_sex                     1
# type                            0
# violation                       7
# vehicle_color                  10
# vehicle_make                   12
# vehicle_registration_state     10
# vehicle_year                   15
# dtype: int64
#
#
#
# ny_statewide
# raw_row_number                   0
# date                             0
# time                             0
# location                       121
# county_name                      0
# subject_age                      0
# subject_race                     0
# subject_sex                      0
# type                             0
# violation                        0
# speed                          661
# posted_speed                   661
# vehicle_color                    8
# vehicle_make                     0
# vehicle_model                 1000
# vehicle_type                     0
# vehicle_registration_state      24
# vehicle_year                    14
# dtype: int64
#
#
#
# oh_cincinnati
# raw_row_number                  0
# date                            0
# time                            0
# location                        0
# lat                             0
# lng                             0
# neighborhood                  826
# beat                          772
# subject_race                    0
# subject_sex                     0
# officer_assignment             18
# type                            0
# disposition                   761
# arrest_made                     0
# citation_issued                 0
# warning_issued                  0
# outcome                       121
# reason_for_stop               877
# vehicle_make                    8
# vehicle_model                  13
# vehicle_registration_state     15
# vehicle_year                   10
# dtype: int64
#
#
#
# oh_columbus
# raw_row_number        0
# date                  0
# time                  0
# location              0
# lat                  77
# lng                  77
# precinct            119
# zone                119
# subject_race          0
# subject_sex           0
# type                  0
# arrest_made           0
# citation_issued       0
# warning_issued        0
# outcome              98
# search_conducted      0
# reason_for_stop       0
# dtype: int64
#
#
#
# oh_statewide
# raw_row_number        0
# date                  0
# time                  0
# location              0
# lat                   0
# lng                   0
# county_name           2
# subject_race         89
# subject_sex          89
# officer_id_hash       0
# department_name       0
# type                  0
# violation           503
# arrest_made           0
# warning_issued        0
# outcome             629
# contraband_found    993
# contraband_drugs    993
# search_conducted      0
# search_basis        959
# dtype: int64
#
#
#
# ok_oklahoma
# raw_row_number                  0
# date                            0
# time                            0
# location                        0
# lat                           106
# lng                           106
# beat                          156
# division                      156
# sector                        156
# subject_age                     9
# subject_race                    6
# subject_sex                     6
# officer_id_hash                 0
# type                          120
# violation                       0
# citation_issued                 0
# outcome                         0
# speed                           0
# posted_speed                    0
# vehicle_color                 156
# vehicle_make                  159
# vehicle_model                 541
# vehicle_registration_state    198
# vehicle_year                  240
# dtype: int64
#
#
#
# ok_tulsa
# raw_row_number                  0
# date                            0
# time                            0
# location                       11
# lat                            90
# lng                            90
# subject_race                   13
# subject_sex                    11
# type                            5
# violation                       0
# speed                         605
# posted_speed                  583
# vehicle_color                  84
# vehicle_make                   68
# vehicle_model                 167
# vehicle_registration_state     64
# vehicle_year                   64
# dtype: int64
#
#
#
# or_statewide
# raw_row_number     0
# date              67
# subject_race       0
# type               0
# dtype: int64
#
#
#
# pa_philadelphia
# raw_row_number        0
# date                  0
# time                  0
# location             21
# lat                  57
# lng                  57
# district              0
# service_area          0
# subject_age           8
# subject_race          0
# subject_sex           0
# type                  0
# arrest_made           0
# outcome             944
# contraband_found    934
# frisk_performed       0
# search_conducted      0
# search_person         0
# search_vehicle        0
# dtype: int64
#
#
#
# ri_statewide
# raw_row_number          0
# date                    0
# time                    0
# zone                    0
# subject_race           66
# subject_sex            66
# department_id           0
# type                    0
# arrest_made            66
# citation_issued        66
# warning_issued         66
# outcome                77
# contraband_found      963
# contraband_drugs      965
# contraband_weapons    974
# contraband_alcohol    999
# contraband_other        0
# frisk_performed         0
# search_conducted        0
# search_basis          963
# reason_for_search     963
# reason_for_stop        66
# vehicle_make          397
# vehicle_model         558
# dtype: int64
#
#
#
# sc_statewide
# raw_row_number           0
# date                     0
# location                 0
# lat                    775
# lng                    775
# county_name              2
# subject_age              0
# subject_race             0
# subject_sex              0
# officer_id_hash         14
# officer_age              5
# officer_race             1
# department_id            0
# type                     0
# violation              325
# arrest_made              0
# citation_issued          0
# outcome                325
# contraband_found       975
# contraband_drugs       975
# contraband_weapons     975
# contraband_alcohol    1000
# contraband_other      1000
# search_conducted         0
# search_person            0
# search_vehicle           0
# reason_for_stop          0
# dtype: int64
#
#
#
# sd_statewide
# raw_row_number                  0
# date                            0
# time                            1
# location                      832
# county_name                     4
# subject_sex                    12
# type                            0
# violation                      13
# citation_issued                 0
# warning_issued                  0
# outcome                         0
# vehicle_color                 247
# vehicle_make                   72
# vehicle_model                 208
# vehicle_registration_state     21
# vehicle_year                  234
# dtype: int64
#
#
#
# tn_statewide
# raw_row_number       0
# date                 0
# time                 0
# location           273
# county_name         15
# subject_race        14
# subject_sex          1
# department_id        0
# department_name      0
# type                 0
# violation           85
# citation_issued      0
# outcome              0
# vehicle_make         4
# vehicle_model       44
# vehicle_year        57
# dtype: int64
#
#
#
# tx_arlington
# raw_row_number         0
# date                   0
# time                   0
# location               0
# lat                    1
# lng                    1
# beat                  13
# district              13
# subject_race           0
# subject_sex            0
# officer_id_hash        0
# type                   0
# outcome             1000
# search_conducted       0
# reason_for_stop        0
# dtype: int64
#
#
#
# tx_austin
# raw_row_number                  0
# date                            0
# subject_age                    29
# subject_race                    3
# subject_sex                    12
# officer_id_hash                 0
# type                          191
# contraband_found              983
# contraband_drugs              985
# contraband_weapons            985
# frisk_performed               972
# search_conducted              183
# search_person                 111
# search_vehicle                159
# search_basis                  962
# reason_for_stop                 0
# vehicle_make                   24
# vehicle_model                 678
# vehicle_registration_state     28
# vehicle_year                  252
# dtype: int64
#
#
#
# tx_houston
# raw_row_number       0
# date                 0
# location            50
# lat                 52
# lng                 52
# beat               105
# district           105
# subject_race       172
# subject_sex          1
# type                 0
# violation            0
# citation_issued      0
# outcome              0
# speed                0
# posted_speed         0
# vehicle_color       35
# vehicle_make        19
# vehicle_model       41
# dtype: int64
#
#
#
# tx_san
# raw_row_number                  0
# date                            0
# time                            0
# location                        0
# lat                             2
# lng                             2
# district                       70
# substation                     70
# subject_age                     1
# subject_race                    2
# subject_sex                     4
# type                           19
# arrest_made                   834
# citation_issued                 0
# outcome                         0
# contraband_found              987
# search_conducted                0
# search_basis                  987
# reason_for_stop                 0
# speed                           0
# posted_speed                    0
# vehicle_color                 133
# vehicle_make                  128
# vehicle_model                 137
# vehicle_registration_state    131
# vehicle_year                  141
# dtype: int64
#
#
#
# tx_statewide
# raw_row_number          0
# date                    0
# time                    0
# location               66
# lat                   414
# lng                   414
# county_name             0
# district               66
# precinct              662
# region                 66
# subject_race            0
# subject_sex             0
# officer_id_hash         0
# type                    0
# violation               0
# citation_issued         0
# warning_issued          0
# outcome                 0
# contraband_found      983
# contraband_drugs      983
# contraband_weapons    983
# search_conducted       66
# search_vehicle        785
# search_basis          983
# vehicle_color         574
# vehicle_make          299
# vehicle_model         362
# vehicle_type            0
# vehicle_year          354
# dtype: int64
#
#
#
# va_statewide
# raw_row_number         0
# date                   0
# location               0
# county_name          132
# subject_race           0
# officer_id_hash        0
# officer_race        1000
# type                   0
# search_conducted       0
# dtype: int64
#
#
#
# vt_burlington
# raw_row_number                  0
# date                            0
# time                            0
# location                        0
# lat                             9
# lng                             9
# subject_age                    12
# subject_race                   26
# subject_sex                    11
# department_name                 0
# type                            0
# violation                       0
# arrest_made                     6
# citation_issued                 6
# warning_issued                  6
# outcome                         7
# contraband_found              986
# search_conducted               11
# search_basis                  986
# reason_for_search             986
# reason_for_stop                 7
# vehicle_registration_state    826
# dtype: int64
#
#
#
# vt_statewide
# raw_row_number         0
# date                   0
# time                   0
# location               0
# lat                   74
# lng                   74
# subject_age            4
# subject_race          13
# subject_sex            2
# officer_id_hash        0
# department_name        0
# type                   0
# arrest_made            8
# citation_issued        8
# warning_issued         8
# outcome                8
# contraband_found     986
# search_conducted       6
# search_basis         986
# reason_for_search    986
# reason_for_stop        6
# dtype: int64
#
#
#
# wa_seattle
# raw_row_number                   0
# date                             0
# time                             0
# location                         0
# lat                             58
# lng                             58
# beat                            71
# precinct                        76
# sector                          71
# subject_age                    670
# subject_race                  1000
# subject_sex                   1000
# officer_id_hash                 41
# type                             0
# violation                        0
# arrest_made                      0
# citation_issued                  0
# warning_issued                   0
# outcome                        414
# reason_for_stop                  0
# vehicle_color                  951
# vehicle_make                   960
# vehicle_model                  961
# vehicle_registration_state     933
# vehicle_year                   998
# dtype: int64
#
#
#
# wa_statewide
# raw_row_number        0
# date                  0
# time                  0
# location             78
# lat                 118
# lng                 118
# county_name         118
# subject_age         265
# subject_race        262
# subject_sex         262
# officer_race          0
# officer_sex           0
# department_name       0
# type                  0
# violation           687
# arrest_made         368
# citation_issued       0
# warning_issued        0
# outcome             275
# contraband_found    977
# frisk_performed     262
# search_conducted    262
# search_basis        977
# dtype: int64
#
#
#
# wa_tacoma
# raw_row_number       0
# date                 0
# time                 0
# location             0
# lat                160
# lng                160
# sector             199
# subsector          199
# officer_id_hash      0
# type                 0
# arrest_made          0
# citation_issued      0
# warning_issued       0
# outcome            355
# reason_for_stop      0
# dtype: int64
#
#
#
# wi_madison
# raw_row_number                  0
# date                            0
# time                            0
# location                       45
# lat                            61
# lng                            61
# district                      126
# sector                        126
# subject_race                   14
# subject_sex                     3
# type                            0
# violation                       3
# citation_issued                 0
# warning_issued                  0
# outcome                         0
# speed                         766
# posted_speed                  766
# vehicle_color                  61
# vehicle_make                   22
# vehicle_model                 738
# vehicle_registration_state      7
# vehicle_year                   17
# dtype: int64
#
#
#
# wi_statewide
# raw_row_number                  0
# date                            0
# time                            0
# location                        0
# lat                           650
# lng                           650
# county_name                     0
# subject_race                  144
# subject_sex                   141
# department_id                   0
# department_name                 0
# type                            0
# violation                       0
# arrest_made                     0
# citation_issued                 0
# warning_issued                  0
# outcome                         3
# contraband_found              990
# contraband_drugs              990
# contraband_weapons            990
# contraband_alcohol            990
# contraband_other              990
# search_conducted              140
# search_person                 140
# search_vehicle                  0
# search_basis                  987
# vehicle_color                 128
# vehicle_make                  122
# vehicle_model                 261
# vehicle_type                  120
# vehicle_registration_state    292
# vehicle_year                  217
# dtype: int64
#
#
#
# wy_statewide
# raw_row_number      0
# date                0
# time                0
# location            8
# county_name        19
# subject_age         4
# subject_race        3
# subject_sex         8
# officer_id_hash     0
# department_id      73
# type                0
# violation           0
# dtype: int64

# %%
sanfran.head()
# Out:
#    Unnamed: 0  raw_row_number        date                 time  \
# 0          48              49  2007-01-01  2019-07-30 13:08:00
# 1         715             716  2007-01-03  2019-07-30 19:15:00
# 2        2443            2444  2007-01-10  2019-07-30 09:10:00
# 3        2481            2482  2007-01-10  2019-07-30 10:35:00
# 4        5000            5001  2007-01-18  2019-07-30 09:25:00
#
#                          location        lat         lng district  \
# 0                 9TH AV/GEARY BL  37.780944 -122.467512        G
# 1                  WALLER/POTOMAC  37.770399 -122.432659        F
# 2           200 HYDE STIONONOTICU  37.782798 -122.415610        J
# 3  17TH STREET AT GUERRERO STREET  37.763177 -122.423928        D
# 4               POTRERO & 24TH ST  37.753001 -122.406421        D
#
#    subject_age   subject_race  ... arrest_made citation_issued  \
# 0         39.0          white  ...       False            True
# 1         24.0  other/unknown  ...       False           False
# 2         39.0          white  ...        True           False
# 3         52.0          black  ...       False            True
# 4         34.0       hispanic  ...       False            True
#
#    warning_issued   outcome  contraband_found search_conducted  \
# 0           False  citation             False            False
# 1            True   warning             False            False
# 2           False    arrest             False            False
# 3           False  citation             False            False
# 4           False  citation             False            False
#
#    search_vehicle  search_basis                            reason_for_stop  \
# 0           False     No search                           Moving Violation
# 1           False     No search  Mechanical or Non-Moving Violation (V.C.)
# 2           False     No search  Mechanical or Non-Moving Violation (V.C.)
# 3           False     No search  Mechanical or Non-Moving Violation (V.C.)
# 4           False     No search  Mechanical or Non-Moving Violation (V.C.)
#
#   hour
# 0   13
# 1   19
# 2    9
# 3   10
# 4    9
#
# [5 rows x 22 columns]

# %%
dfs['ca_sanfran'] = sanfran

# %%
sanfran.isnull().sum()
# Out:
# Unnamed: 0          0
# raw_row_number      0
# date                0
# time                0
# location            0
# lat                 0
# lng                 0
# district            0
# subject_age         0
# subject_race        0
# subject_sex         0
# type                0
# arrest_made         0
# citation_issued     0
# warning_issued      0
# outcome             0
# contraband_found    0
# search_conducted    0
# search_vehicle      0
# search_basis        0
# reason_for_stop     0
# hour                0
# dtype: int64

# %%
dfs['ar_little'].isnull().sum()
# Out:
# raw_row_number     0
# date               0
# time               0
# lat                0
# lng                0
# subject_age        0
# subject_race       0
# subject_sex        0
# type               0
# citation_issued    0
# outcome            0
# vehicle_type       0
# dtype: int64

# %%
s = dfs['ar_little']['subject_age'].value_counts(normalize=True)
missing = dfs['ar_little']['subject_age'].isnull()
dfs['ar_little'].loc[missing, 'subject_age'] = np.random.choice(s.index, size=len(dfs['ar_little'][missing]), p=s.values)

# %%
len(dfs['ar_little'][missing])
# Out:
# 3

# %%
s = dfs['ar_little']['subject_sex'].value_counts(normalize=True)
missing = dfs['ar_little']['subject_sex'].isnull()
dfs['ar_little'].loc[missing, 'subject_sex'] = np.random.choice(s.index, size=len(dfs['ar_little'][missing]), p=s.values)

# %%
dfs['az_gilbert'].isnull().sum()
# Out:
# raw_row_number        0
# date                  0
# time                  0
# location              0
# lat                   1
# lng                   1
# officer_id_hash       0
# type                  0
# vehicle_color       999
# vehicle_make        999
# vehicle_model      1000
# vehicle_year       1000
# dtype: int64

# %%
dfs.keys()
# Out:
# dict_keys(['ar_little', 'az_gilbert', 'az_mesa', 'az_statewide', 'ca_anaheim', 'ca_bakersfield', 'ca_long', 'ca_san', 'ca_santa', 'ca_statewide', 'ca_stockton', 'co_aurora', 'co_denver', 'co_statewide', 'ct_hartford', 'ct_statewide', 'fl_saint', 'fl_statewide', 'fl_tampa', 'ga_statewide', 'ia_statewide', 'id_idaho', 'il_chicago', 'il_statewide', 'in_fort', 'ks_wichita', 'ky_owensboro', 'la_new', 'ma_statewide', 'md_baltimore', 'md_statewide', 'mi_statewide', 'mn_saint', 'mo_statewide', 'ms_statewide', 'mt_statewide', 'nc_charlotte', 'nc_durham', 'nc_fayetteville', 'nc_greensboro', 'nc_raleigh', 'nc_statewide', 'nc_winston-salem', 'nd_grand', 'nd_statewide', 'ne_statewide', 'nh_statewide', 'nj_camden', 'nj_statewide', 'nv_statewide', 'ny_albany', 'ny_statewide', 'oh_cincinnati', 'oh_columbus', 'oh_statewide', 'ok_oklahoma', 'ok_tulsa', 'or_statewide', 'pa_philadelphia', 'ri_statewide', 'sc_statewide', 'sd_statewide', 'tn_statewide', 'tx_arlington', 'tx_austin', 'tx_houston', 'tx_san', 'tx_statewide', 'va_statewide', 'vt_burlington', 'vt_statewide', 'wa_seattle', 'wa_statewide', 'wa_tacoma', 'wi_madison', 'wi_statewide', 'wy_statewide', 'ca_sanfran'])

# %%
keys_ex = ['ar_little', 
           'az_gilbert', 
           'az_mesa', 
           'az_statewide', 
           'ca_anaheim', 
           'ca_bakersfield', 
           'ca_long', 
           'ca_san', 
           'ca_santa', 
           'ca_statewide', 
           'ca_stockton', 
           'co_aurora', 
           'co_denver', 
           'co_statewide', 
           'ct_hartford', 
           'ct_statewide', 
           'fl_saint', 
           'fl_statewide', 
           'fl_tampa', 
           'ga_statewide', 
           'ia_statewide', 
           'id_idaho', 
           'il_chicago', 
           'il_statewide', 
           'in_fort', 'ks_wichita', 'ky_owensboro', 
           'la_new', 'ma_statewide', 'md_baltimore', 
           'md_statewide', 'mi_statewide', 'mn_saint', 
           'mo_statewide', 'ms_statewide', 'mt_statewide', 
           'nc_charlotte', 'nc_durham', 'nc_fayetteville', 
           'nc_greensboro', 'nc_raleigh', 'nc_statewide', 
           'nc_winston-salem', 'nd_grand', 'nd_statewide', 
           'ne_statewide', 'nh_statewide', 'nj_camden', 
           'nj_statewide', 'nv_statewide', 'ny_albany', 
           'ny_statewide', 'oh_cincinnati', 'oh_columbus', 
           'oh_statewide', 'ok_oklahoma', 'ok_tulsa', 
           'or_statewide', 
           'pa_philadelphia', 'ri_statewide', 
           'sc_statewide', 'sd_statewide', 'tn_statewide', 
           'tx_arlington', 'tx_austin', 'tx_houston', 
           'tx_san', 'tx_statewide', 'va_statewide', 
           'vt_burlington', 'vt_statewide', 'wa_seattle', 
           'wa_statewide', 'wa_tacoma', 'wi_madison', 
           'wi_statewide', 'wy_statewide', 'ca_sanfran']

# %%
state_patrol = []
for k in keys_ex:
    if 'statewide' in k:
        state_patrol.append(k)

# %%
state_patrol = ['az_statewide',
 'ca_statewide',
 'co_statewide',
 'ct_statewide',
 'fl_statewide',
 'ga_statewide',
 'ia_statewide',
 'il_statewide',
 'ma_statewide',
 'md_statewide',
 'mi_statewide',
# 'mo_statewide',
# 'ms_statewide',
 'mt_statewide',
 'nc_statewide',
# 'nd_statewide',
# 'ne_statewide',
 'nh_statewide',
 'nj_statewide',
 'nv_statewide',
# 'ny_statewide',
 'oh_statewide',
# 'or_statewide',
 'ri_statewide',
 'sc_statewide',
 'sd_statewide',
 'tn_statewide',
 'tx_statewide',
# 'va_statewide',
 'vt_statewide',
 'wa_statewide',
 'wi_statewide',
# 'wy_statewide'
               ]

# %%
state_patrol
# Out:
# ['az_statewide',
#  'ca_statewide',
#  'co_statewide',
#  'ct_statewide',
#  'fl_statewide',
#  'ga_statewide',
#  'ia_statewide',
#  'il_statewide',
#  'ma_statewide',
#  'md_statewide',
#  'mi_statewide',
#  'mt_statewide',
#  'nc_statewide',
#  'nh_statewide',
#  'nj_statewide',
#  'nv_statewide',
#  'oh_statewide',
#  'ri_statewide',
#  'sc_statewide',
#  'sd_statewide',
#  'tn_statewide',
#  'tx_statewide',
#  'vt_statewide',
#  'wa_statewide',
#  'wi_statewide']

# %%
result = set(dfs['ca_sanfran'].columns)
for k in state_patrol:
    result.intersection_update(dfs[k].columns)
    print(result)
result
# Out:
# {'reason_for_stop', 'search_conducted', 'location', 'search_basis', 'raw_row_number', 'subject_sex', 'outcome', 'type', 'time', 'date', 'warning_issued', 'search_vehicle', 'citation_issued', 'subject_race', 'arrest_made', 'contraband_found'}
# {'reason_for_stop', 'search_conducted', 'subject_race', 'raw_row_number', 'subject_sex', 'search_basis', 'outcome', 'date', 'warning_issued', 'citation_issued', 'type', 'arrest_made', 'contraband_found'}
# {'search_conducted', 'subject_race', 'raw_row_number', 'subject_sex', 'search_basis', 'outcome', 'date', 'warning_issued', 'citation_issued', 'type', 'arrest_made', 'contraband_found'}
# {'search_conducted', 'subject_race', 'raw_row_number', 'subject_sex', 'search_basis', 'outcome', 'date', 'warning_issued', 'citation_issued', 'type', 'arrest_made', 'contraband_found'}
# {'search_conducted', 'subject_race', 'raw_row_number', 'subject_sex', 'search_basis', 'outcome', 'date', 'warning_issued', 'citation_issued', 'type', 'arrest_made'}
# {'subject_race', 'raw_row_number', 'subject_sex', 'outcome', 'date', 'type'}
# {'subject_race', 'raw_row_number', 'subject_sex', 'outcome', 'date', 'type'}
# {'subject_race', 'raw_row_number', 'subject_sex', 'outcome', 'date', 'type'}
# {'subject_race', 'raw_row_number', 'subject_sex', 'outcome', 'date', 'type'}
# {'subject_race', 'raw_row_number', 'subject_sex', 'outcome', 'date', 'type'}
# {'subject_race', 'raw_row_number', 'outcome', 'date', 'type'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'type', 'date', 'raw_row_number', 'subject_race'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}
# {'date', 'raw_row_number', 'type'}

# %%
dfs['ca_sanfran'].columns
# Out:
# Index(['Unnamed: 0', 'raw_row_number', 'date', 'time', 'location', 'lat',
#        'lng', 'district', 'subject_age', 'subject_race', 'subject_sex', 'type',
#        'arrest_made', 'citation_issued', 'warning_issued', 'outcome',
#        'contraband_found', 'search_conducted', 'search_vehicle',
#        'search_basis', 'reason_for_stop', 'hour'],
#       dtype='object')

# %%
dfs['ar_little'].columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'lat', 'lng', 'subject_age',
#        'subject_race', 'subject_sex', 'type', 'citation_issued', 'outcome',
#        'vehicle_type'],
#       dtype='object')

# %%
dfs['az_gilbert'].columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'location', 'lat', 'lng',
#        'officer_id_hash', 'type', 'vehicle_color', 'vehicle_make',
#        'vehicle_model', 'vehicle_year'],
#       dtype='object')

# %%
sanfran.dtypes
# Out:
# Unnamed: 0            int64
# raw_row_number        int64
# date                 object
# time                 object
# location             object
# lat                 float64
# lng                 float64
# district             object
# subject_age         float64
# subject_race         object
# subject_sex          object
# type                 object
# arrest_made            bool
# citation_issued        bool
# warning_issued         bool
# outcome              object
# contraband_found       bool
# search_conducted       bool
# search_vehicle         bool
# search_basis         object
# reason_for_stop      object
# hour                  int64
# dtype: object

# %%
type(sanfran['date'].values[0])
# Out:
# str

# %%
def cleanup(df):

# %%
all_cols = []

for k in keys_ex:
    cols = dfs[k].columns
    for c in cols:
        if c not in all_cols:
            all_cols.append(c)

col_in_df = {}

for c in all_cols:
    col_in_df[c] = []
    for k in keys_ex:
        if c in dfs[k].columns:
            col_in_df[c].append(k)

# %%
sorted(all_cols)
# Out:
# ['Unnamed: 0',
#  'arrest_made',
#  'beat',
#  'citation_issued',
#  'contraband_alcohol',
#  'contraband_drugs',
#  'contraband_found',
#  'contraband_other',
#  'contraband_weapons',
#  'county_name',
#  'date',
#  'department_id',
#  'department_name',
#  'disposition',
#  'district',
#  'division',
#  'frisk_performed',
#  'hour',
#  'lat',
#  'lng',
#  'location',
#  'neighborhood',
#  'officer_age',
#  'officer_assignment',
#  'officer_id_hash',
#  'officer_race',
#  'officer_sex',
#  'officer_years_of_service',
#  'outcome',
#  'police_grid_number',
#  'posted_speed',
#  'precinct',
#  'raw_row_number',
#  'reason_for_arrest',
#  'reason_for_frisk',
#  'reason_for_search',
#  'reason_for_stop',
#  'region',
#  'search_basis',
#  'search_conducted',
#  'search_person',
#  'search_vehicle',
#  'sector',
#  'service_area',
#  'speed',
#  'subdistrict',
#  'subdivision',
#  'subject_age',
#  'subject_race',
#  'subject_sex',
#  'subsector',
#  'substation',
#  'time',
#  'type',
#  'unit',
#  'use_of_force_description',
#  'use_of_force_reason',
#  'vehicle_color',
#  'vehicle_make',
#  'vehicle_model',
#  'vehicle_registration_state',
#  'vehicle_type',
#  'vehicle_year',
#  'violation',
#  'warning_issued',
#  'zone']

# %%
sanfran['outcome'].value_counts()
# Out:
# citation         713
# warning          251
# Not on record     23
# arrest            13
# Name: outcome, dtype: int64

# %%
sanfran.columns
# Out:
# Index(['Unnamed: 0', 'raw_row_number', 'date', 'time', 'location', 'lat',
#        'lng', 'district', 'subject_age', 'subject_race', 'subject_sex', 'type',
#        'arrest_made', 'citation_issued', 'warning_issued', 'outcome',
#        'contraband_found', 'search_conducted', 'search_vehicle',
#        'search_basis', 'reason_for_stop', 'hour'],
#       dtype='object')

# %%
all_cols_sp = []

for k in state_patrol:
    cols = dfs[k].columns
    for c in cols:
        if c not in all_cols_sp:
            all_cols_sp.append(c)

col_in_df_sp = {}

for c in all_cols_sp:
    col_in_df_sp[c] = []
    for k in state_patrol:
        if c in dfs[k].columns:
            col_in_df_sp[c].append(k)

# %%
counts_spd = {}
for k in col_in_df_sp.keys():
    counts_spd[k] = sum(1 for c in col_in_df_sp[k])

# %%
counts_spl = []
for k in col_in_df_sp.keys():
    counts_spl.append((k, sum(1 for c in col_in_df_sp[k])))

# %%
sorted(counts_spl, key=lambda x: x[1], reverse=True)
# Out:
# [('raw_row_number', 33),
#  ('date', 33),
#  ('type', 33),
#  ('subject_race', 32),
#  ('location', 28),
#  ('subject_sex', 27),
#  ('violation', 25),
#  ('outcome', 25),
#  ('time', 24),
#  ('county_name', 24),
#  ('citation_issued', 23),
#  ('warning_issued', 22),
#  ('search_conducted', 21),
#  ('arrest_made', 18),
#  ('department_name', 18),
#  ('subject_age', 18),
#  ('contraband_found', 16),
#  ('search_basis', 16),
#  ('officer_id_hash', 15),
#  ('reason_for_stop', 13),
#  ('vehicle_make', 11),
#  ('contraband_drugs', 10),
#  ('vehicle_year', 10),
#  ('lat', 10),
#  ('lng', 10),
#  ('vehicle_model', 10),
#  ('department_id', 9),
#  ('search_vehicle', 8),
#  ('vehicle_registration_state', 8),
#  ('contraband_weapons', 8),
#  ('search_person', 7),
#  ('frisk_performed', 7),
#  ('vehicle_color', 7),
#  ('vehicle_type', 6),
#  ('reason_for_search', 6),
#  ('contraband_other', 5),
#  ('officer_race', 4),
#  ('contraband_alcohol', 4),
#  ('officer_sex', 3),
#  ('district', 2),
#  ('officer_age', 2),
#  ('officer_years_of_service', 1),
#  ('unit', 1),
#  ('beat', 1),
#  ('disposition', 1),
#  ('reason_for_arrest', 1),
#  ('reason_for_frisk', 1),
#  ('speed', 1),
#  ('posted_speed', 1),
#  ('zone', 1),
#  ('precinct', 1),
#  ('region', 1)]

# %%
col_in_df_sp
# Out:
# {'raw_row_number': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mo_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'ne_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'or_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'date': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mo_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'ne_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'or_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'time': ['az_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'location': ['az_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mo_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'ne_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'county_name': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'ma_statewide',
#   'mi_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'nh_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'subject_race': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mo_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'ne_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'or_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'subject_sex': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'officer_id_hash': ['az_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'mi_statewide',
#   'nc_statewide',
#   'nj_statewide',
#   'oh_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'vt_statewide',
#   'wy_statewide'],
#  'type': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mo_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'ne_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'or_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'violation': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nd_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'ny_statewide',
#   'oh_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'wa_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'arrest_made': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'citation_issued': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'warning_issued': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sd_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'outcome': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nh_statewide',
#   'nj_statewide',
#   'nv_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'contraband_found': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mo_statewide',
#   'nc_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'contraband_drugs': ['az_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'nc_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'contraband_other': ['az_statewide',
#   'ma_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'wi_statewide'],
#  'search_conducted': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mo_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'ne_statewide',
#   'nj_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'va_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'search_person': ['az_statewide',
#   'ca_statewide',
#   'il_statewide',
#   'md_statewide',
#   'nc_statewide',
#   'sc_statewide',
#   'wi_statewide'],
#  'search_vehicle': ['az_statewide',
#   'ct_statewide',
#   'il_statewide',
#   'md_statewide',
#   'nc_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'search_basis': ['az_statewide',
#   'ca_statewide',
#   'co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'oh_statewide',
#   'ri_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'reason_for_stop': ['az_statewide',
#   'ca_statewide',
#   'ct_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'vt_statewide'],
#  'vehicle_type': ['az_statewide',
#   'ma_statewide',
#   'mt_statewide',
#   'ny_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'vehicle_year': ['az_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'mt_statewide',
#   'ny_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'district': ['ca_statewide', 'tx_statewide'],
#  'department_name': ['ca_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'md_statewide',
#   'mi_statewide',
#   'mo_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'ne_statewide',
#   'oh_statewide',
#   'tn_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'frisk_performed': ['ca_statewide',
#   'fl_statewide',
#   'ma_statewide',
#   'nc_statewide',
#   'nj_statewide',
#   'ri_statewide',
#   'wa_statewide'],
#  'reason_for_search': ['ca_statewide',
#   'fl_statewide',
#   'md_statewide',
#   'nc_statewide',
#   'ri_statewide',
#   'vt_statewide'],
#  'subject_age': ['co_statewide',
#   'ct_statewide',
#   'fl_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'ms_statewide',
#   'mt_statewide',
#   'nc_statewide',
#   'nd_statewide',
#   'nh_statewide',
#   'nv_statewide',
#   'ny_statewide',
#   'sc_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wy_statewide'],
#  'officer_sex': ['co_statewide', 'fl_statewide', 'wa_statewide'],
#  'lat': ['ct_statewide',
#   'ga_statewide',
#   'mt_statewide',
#   'nh_statewide',
#   'oh_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'lng': ['ct_statewide',
#   'ga_statewide',
#   'mt_statewide',
#   'nh_statewide',
#   'oh_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'vt_statewide',
#   'wa_statewide',
#   'wi_statewide'],
#  'officer_age': ['fl_statewide', 'sc_statewide'],
#  'officer_race': ['fl_statewide',
#   'sc_statewide',
#   'va_statewide',
#   'wa_statewide'],
#  'officer_years_of_service': ['fl_statewide'],
#  'unit': ['fl_statewide'],
#  'vehicle_registration_state': ['fl_statewide',
#   'ia_statewide',
#   'ma_statewide',
#   'mt_statewide',
#   'nj_statewide',
#   'ny_statewide',
#   'sd_statewide',
#   'wi_statewide'],
#  'vehicle_color': ['ga_statewide',
#   'ia_statewide',
#   'nj_statewide',
#   'ny_statewide',
#   'sd_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'vehicle_make': ['ga_statewide',
#   'ia_statewide',
#   'il_statewide',
#   'mt_statewide',
#   'nj_statewide',
#   'ny_statewide',
#   'ri_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'vehicle_model': ['ga_statewide',
#   'ia_statewide',
#   'mt_statewide',
#   'nj_statewide',
#   'ny_statewide',
#   'ri_statewide',
#   'sd_statewide',
#   'tn_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'beat': ['il_statewide'],
#  'department_id': ['il_statewide',
#   'mi_statewide',
#   'ms_statewide',
#   'nj_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'tn_statewide',
#   'wi_statewide',
#   'wy_statewide'],
#  'contraband_weapons': ['il_statewide',
#   'ma_statewide',
#   'md_statewide',
#   'nc_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'tx_statewide',
#   'wi_statewide'],
#  'contraband_alcohol': ['ma_statewide',
#   'ri_statewide',
#   'sc_statewide',
#   'wi_statewide'],
#  'disposition': ['md_statewide'],
#  'reason_for_arrest': ['md_statewide'],
#  'reason_for_frisk': ['nc_statewide'],
#  'speed': ['ny_statewide'],
#  'posted_speed': ['ny_statewide'],
#  'zone': ['ri_statewide'],
#  'precinct': ['tx_statewide'],
#  'region': ['tx_statewide']}

# %%
sanfran.columns
# Out:
# Index(['Unnamed: 0', 'raw_row_number', 'date', 'time', 'location', 'lat',
#        'lng', 'district', 'subject_age', 'subject_race', 'subject_sex', 'type',
#        'arrest_made', 'citation_issued', 'warning_issued', 'outcome',
#        'contraband_found', 'search_conducted', 'search_vehicle',
#        'search_basis', 'reason_for_stop', 'hour'],
#       dtype='object')

# %%
features = ['state', 'hour', 'night', 'location', 'lat', 'lng', 'district', 'subject_age', 'subject_race', 'subject_sex', 'type']
targets = ['none', 'citation', 'arrest', 'search']

# %%
stpd = {}
for k in state_patrol:
    stpd[k] = dfs[k]

# %%
stpd_df = pd.DataFrame(columns=features+targets)

# %%
testdf = stpd_df

# %%
stpd.keys()
# Out:
# dict_keys(['az_statewide', 'ca_statewide', 'co_statewide', 'ct_statewide', 'fl_statewide', 'ga_statewide', 'ia_statewide', 'il_statewide', 'ma_statewide', 'md_statewide', 'mi_statewide', 'mo_statewide', 'ms_statewide', 'mt_statewide', 'nc_statewide', 'nd_statewide', 'ne_statewide', 'nh_statewide', 'nj_statewide', 'nv_statewide', 'ny_statewide', 'oh_statewide', 'or_statewide', 'ri_statewide', 'sc_statewide', 'sd_statewide', 'tn_statewide', 'tx_statewide', 'va_statewide', 'vt_statewide', 'wa_statewide', 'wi_statewide', 'wy_statewide'])

# %%
for col in stpd['az_statewide']:
    print(col, end=' ')
# Out:
# raw_row_number date time location county_name subject_race subject_sex officer_id_hash type violation arrest_made citation_issued warning_issued outcome contraband_found contraband_drugs contraband_other search_conducted search_person search_vehicle search_basis reason_for_stop vehicle_type vehicle_year

# %%
testdf['state'] = ['Az' for _ in range(len(stpd['az_statewide']['time']))]
testdf['hour'] = pd.to_datetime(stpd['az_statewide']['time']).dt.hour
testdf['night'] = pd.to_datetime(stpd['az_statewide']['time']).dt.hour.apply(lambda x: 0 if ((x > 6) & (x < 19)) else 1)
testdf['location'] = stpd['az_statewide']['location']
testdf['lat'] = [33.7 for _ in range(len(stpd['az_statewide']['time']))]
testdf['lng'] = [-111.4 for _ in range(len(stpd['az_statewide']['time']))]
testdf['district'] = stpd['az_statewide']['county_name']
testdf['subject_age'] = [200 for _ in range(len(stpd['az_statewide']['time']))]
testdf['subject_race'] = stpd['az_statewide']['subject_race']
testdf['subject_sex'] = stpd['az_statewide']['subject_sex']
testdf['type'] = stpd['az_statewide']['type']
testdf['none'] = stpd['az_statewide']['outcome'].apply(lambda x: 0 if (x == 'arrest') or (x == 'citation') else 1)
testdf['citation'] = stpd['az_statewide']['outcome'].apply(lambda x: 1 if x == 'citation' else 0)
testdf['arrest'] = stpd['az_statewide']['outcome'].apply(lambda x: 1 if x == 'arrest' else 0)
testdf['search'] = stpd['az_statewide']['search_conducted'].apply(lambda x: 1 if (x == True) else 0)

# %%
stpd_df = testdf

# %%
testdf.head()
# Out:
#   state  hour  night   location   lat    lng         district  subject_age  \
# 0    Az    10      0   US60 180  33.7 -111.4  Maricopa County          200
# 1    Az    13      0   US60 186  33.7 -111.4  Maricopa County          200
# 2    Az    11      0  SR202 186  33.7 -111.4  Maricopa County          200
# 3    Az    10      0    I17 221  33.7 -111.4  Maricopa County          200
# 4    Az    11      0   US60 199  33.7 -111.4     Pinal County          200
#
#   subject_race subject_sex       type  none  citation  arrest  search
# 0        white      female  vehicular     1         0       0       0
# 1        white        male  vehicular     1         0       0       0
# 2        white        male  vehicular     1         0       0       0
# 3        white        male  vehicular     0         1       0       0
# 4     hispanic        male  vehicular     0         1       0       0

# %%
for col in stpd['ca_statewide']:
    print(col, end=' ')
# Out:
# raw_row_number date county_name district subject_race subject_sex department_name type violation arrest_made citation_issued warning_issued outcome contraband_found frisk_performed search_conducted search_person search_basis reason_for_search reason_for_stop

# %%
testdf['state'] = ['Ca' for _ in range(len(stpd['ca_statewide']['raw_row_number']))]
testdf['hour'] = [100 for _ in range(len(stpd['ca_statewide']['raw_row_number']))]
testdf['night'] = [2 for _ in range(len(stpd['ca_statewide']['raw_row_number']))]
testdf['location'] = stpd['ca_statewide']['department_name']
testdf['lat'] = [36.1 for _ in range(len(stpd['ca_statewide']['raw_row_number']))]
testdf['lng'] = [-119.6 for _ in range(len(stpd['ca_statewide']['raw_row_number']))]
testdf['district'] = stpd['ca_statewide']['district']
testdf['subject_age'] = [200 for _ in range(len(stpd['ca_statewide']['raw_row_number']))]
testdf['subject_race'] = stpd['ca_statewide']['subject_race']
testdf['subject_sex'] = stpd['ca_statewide']['subject_sex']
testdf['type'] = stpd['ca_statewide']['type']
testdf['none'] = stpd['ca_statewide']['outcome'].apply(lambda x: 0 if ((x == 'arrest') or (x == 'summons')) or (x == 'citation') else 1)
testdf['citation'] = stpd['ca_statewide']['outcome'].apply(lambda x: 1 if ((x == 'citation') or (x == 'summons')) else 0)
testdf['arrest'] = stpd['ca_statewide']['outcome'].apply(lambda x: 1 if x == 'arrest' else 0)
testdf['search'] = stpd['ca_statewide']['search_conducted'].apply(lambda x: 1 if (x == True) else 0)

# %%
stpd_df = testdf.append(stpd_df, ignore_index=True)

# %%
for col in stpd['co_statewide']:
    print(col, end=' ')
# Out:
# raw_row_number date time location county_name subject_age subject_race subject_sex officer_id_hash officer_sex type violation arrest_made citation_issued warning_issued outcome contraband_found search_conducted search_basis

# %%
state = 'ct_statewide'
testdf['state'] = ['Co' for _ in range(len(stpd['co_statewide']['raw_row_number']))]
testdf['hour'] = [100 for _ in range(len(stpd['co_statewide']['raw_row_number']))]
testdf['night'] = [2 for _ in range(len(stpd['co_statewide']['raw_row_number']))]
testdf['location'] = stpd['co_statewide']['location']
testdf['lat'] = [39.1 for _ in range(len(stpd['co_statewide']['raw_row_number']))]
testdf['lng'] = [-105.3 for _ in range(len(stpd['co_statewide']['raw_row_number']))]
testdf['district'] = stpd['co_statewide']['county_name']
testdf['subject_age'] = [200 for _ in range(len(stpd['co_statewide']['raw_row_number']))]
testdf['subject_race'] = stpd['co_statewide']['subject_race']
testdf['subject_sex'] = stpd['co_statewide']['subject_sex']
testdf['type'] = stpd['co_statewide']['type']
testdf['none'] = stpd['co_statewide']['outcome'].apply(lambda x: 0 if ((x == 'arrest') or (x == 'summons')) or (x == 'citation') else 1)
testdf['citation'] = stpd['co_statewide']['outcome'].apply(lambda x: 1 if ((x == 'citation') or (x == 'summons')) else 0)
testdf['arrest'] = stpd['co_statewide']['outcome'].apply(lambda x: 1 if x == 'arrest' else 0)
testdf['search'] = stpd['co_statewide']['search_conducted'].apply(lambda x: 1 if (x == True) else 0)

# %%
stpd_df = testdf.append(stpd_df)

# %%
stpd_df.shape
# Out:
# (3000, 15)

# %%
state_str = 'ct_statewide'
state_abb = 'Ct'
hour = [100 for _ in range(len(stpd[state_str]['raw_row_number']))]
night = [0 for _ in range(len(stpd[state_str]['raw_row_number']))]
loc = stpd[state_str]['location']
lat = 
lng = 
district = 
age = 
race = 'unknown'
sex = {'male':0, 'female':1, 'unknown':2}

none_func = stpd[state_str]['outcome'].apply(lambda x: 0 if ((x == 'arrest') or (x == 'summons')) or (x == 'citation') else 1)

citation_func = stpd[state_str]['outcome'].apply(lambda x: 1 if ((x == 'citation') or (x == 'summons')) else 0)

arrest_func = stpd[state_str]['outcome'].apply(lambda x: 1 if x == 'arrest' else 0)

search_func = ([x for x in stpd[state_str]['search_conducted'].fillna(False).astype(int)] 
              if stpd[state_str].columns.contains('search_conducted')
              else [0 for _ in range(len(stpd[state_str]['raw_row_number']))])

testdf['state'] = [state_abb for _ in range(len(stpd[state_str]['raw_row_number']))]
testdf['hour'] = hour
testdf['night'] = night
testdf['location'] = loc
testdf['lat'] = [lat for _ in range(len(stpd[state_str]['raw_row_number']))]
testdf['lng'] = [lng for _ in range(len(stpd[state_str]['raw_row_number']))]
testdf['district'] = stpd[state_str][district]
testdf['subject_age'] = (round(stpd[state_str]['subject_age'].fillna(200)) 
                         if stpd[state_str].columns.contains('subject_age') 
                         else [age for _ in range(len(stpd[state_str]['raw_row_number']))])
testdf['subject_race'] = (stpd[state_str]['subject_race'].fillna('unknown')
                         if stpd[state_str].columns.contains('subject_race') 
                         else [race for _ in range(len(stpd[state_str]['raw_row_number']))])
testdf['subject_sex'] = ([sex[x] for x in stpd[state_str]['subject_sex'][:5].fillna('unknown')]
                         if stpd[state_str].columns.contains('subject_sex')
                         else [sex['unknown'] for _ in range(len(stpd[state_str]['raw_row_number'][:5]))])
testdf['type'] = stpd[state_str]['type']
testdf['none'] = stpd[state_str]['outcome'].apply(lambda x: 0 if ((x == 'arrest') or (x == 'summons')) or (x == 'citation') else 1)
testdf['citation'] = stpd[state_str]['outcome'].apply(lambda x: 1 if ((x == 'citation') or (x == 'summons')) else 0)
testdf['arrest'] = stpd[state_str]['outcome'].apply(lambda x: 1 if x == 'arrest' else 0)
testdf['search'] = stpd[state_str]['search_conducted'].apply(lambda x: 1 if (x == True) else 0)

# %%
for st in state_patrol:
    state_str = st
    age = 200
    print(state_str)
    print(sum(list(round(stpd[state_str]['subject_age'].fillna(200)) 
                             if stpd[state_str].columns.contains('subject_age') 
                             else [age for _ in range(len(stpd[state_str]['raw_row_number']))])))
    print(sum(1 for _ in stpd[state_str]['subject_race'].fillna('unknown')))
# Out:
# az_statewide
# 200000
# 1000
# ca_statewide
# 200000
# 1000
# co_statewide
# 77839.0
# 1000
# ct_statewide
# 38639.0
# 1000
# fl_statewide
# 77338.0
# 1000
# ga_statewide
# 200000
# 1000
# ia_statewide
# 138167.0
# 1000
# il_statewide
# 31678.0
# 870
# ma_statewide
# 44148.0
# 1000
# md_statewide
# 167088.0
# 1000
# mi_statewide
# 199000
# 995
# mo_statewide
# 200000
# 1000
# ms_statewide
# 34582.0
# 1000
# mt_statewide
# 40549.0
# 1000
# nc_statewide
# 35158
# 1000
# nd_statewide
# 35577
# 1000
# ne_statewide
# 200000
# 1000
# nh_statewide
# 115415.0
# 1000
# nj_statewide
# 199800
# 999
# nv_statewide
# 50605.0
# 1000
# ny_statewide
# 36173
# 1000
# oh_statewide
# 200000
# 1000
# or_statewide
# 200000
# 1000
# ri_statewide
# 200000
# 1000
# sc_statewide
# 36633
# 1000
# sd_statewide
# 200000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subject_race'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-408-8f7734bace85> in <module>
#       6                              if stpd[state_str].columns.contains('subject_age')
#       7                              else [age for _ in range(len(stpd[state_str]['raw_row_number']))])))
# ----> 8     print(sum(1 for _ in stpd[state_str]['subject_race'].fillna('unknown')))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subject_race'

# %%
for st in state_patrol:
    state_str = st
    sex = {'male':0, 'female':1, 'unknown':2}
    print(state_str)
    print([sex[x] for x in stpd[state_str]['subject_sex'][:5].fillna('unknown')]
         if stpd[state_str].columns.contains('subject_sex')
         else [sex['unknown'] for _ in range(len(stpd[state_str]['raw_row_number'][:5]))])
    print('\n')
# Out:
# az_statewide
# [1, 0, 0, 0, 0]
#
#
# ca_statewide
# [0, 0, 0, 1, 0]
#
#
# co_statewide
# [1, 0, 1, 1, 2]
#
#
# ct_statewide
# [0, 1, 0, 0, 1]
#
#
# fl_statewide
# [1, 1, 1, 0, 0]
#
#
# ga_statewide
# [1, 0, 0, 0, 1]
#
#
# ia_statewide
# [2, 0, 0, 2, 2]
#
#
# il_statewide
# [0, 1, 0, 0, 0]
#
#
# ma_statewide
# [1, 0, 0, 0, 0]
#
#
# md_statewide
# [0, 1, 0, 0, 0]
#
#
# mi_statewide
# [2, 2, 2, 2, 2]
#
#
# mo_statewide
# [2, 2, 2, 2, 2]
#
#
# ms_statewide
# [0, 1, 0, 0, 1]
#
#
# mt_statewide
# [0, 0, 0, 1, 0]
#
#
# nc_statewide
# [0, 0, 0, 0, 0]
#
#
# nd_statewide
# [1, 0, 1, 1, 0]
#
#
# ne_statewide
# [2, 2, 2, 2, 2]
#
#
# nh_statewide
# [0, 1, 0, 0, 0]
#
#
# nj_statewide
# [0, 0, 0, 0, 0]
#
#
# nv_statewide
# [2, 2, 2, 2, 2]
#
#
# ny_statewide
# [0, 1, 0, 1, 0]
#
#
# oh_statewide
# [2, 0, 0, 0, 0]
#
#
# or_statewide
# [2, 2, 2, 2, 2]
#
#
# ri_statewide
# [0, 0, 0, 0, 0]
#
#
# sc_statewide
# [1, 0, 0, 1, 0]
#
#
# sd_statewide
# [1, 0, 0, 2, 0]
#
#
# tn_statewide
# [0, 1, 0, 0, 0]
#
#
# tx_statewide
# [0, 1, 1, 0, 0]
#
#
# va_statewide
# [2, 2, 2, 2, 2]
#
#
# vt_statewide
# [0, 0, 0, 0, 1]
#
#
# wa_statewide
# [0, 0, 0, 1, 1]
#
#
# wi_statewide
# [1, 1, 0, 0, 0]
#
#
# wy_statewide
# [0, 0, 0, 1, 0]

# %%
for st in state_patrol:
    state_str = st
    print(state_str)
    print(stpd[state_str]['outcome'].value_counts()
         if stpd[state_str].columns.contains('outcome')
         else stpd[state_str].columns)
    print('\n')
# Out:
# az_statewide
# citation    481
# warning     388
# arrest       24
# Name: outcome, dtype: int64
#
#
# ca_statewide
# summons     484
# warning     167
# arrest       30
# citation     22
# Name: outcome, dtype: int64
#
#
# co_statewide
# warning     271
# citation    165
# arrest        3
# Name: outcome, dtype: int64
#
#
# ct_statewide
# citation    478
# warning     424
# summons      58
# arrest       25
# Name: outcome, dtype: int64
#
#
# fl_statewide
# citation    748
# warning     207
# arrest       24
# Name: outcome, dtype: int64
#
#
# ga_statewide
# warning    1000
# Name: outcome, dtype: int64
#
#
# ia_statewide
# warning     429
# citation    409
# Name: outcome, dtype: int64
#
#
# il_statewide
# warning     486
# citation    384
# Name: outcome, dtype: int64
#
#
# ma_statewide
# citation    639
# warning     330
# arrest       30
# Name: outcome, dtype: int64
#
#
# md_statewide
# warning     461
# citation    303
# arrest       16
# Name: outcome, dtype: int64
#
#
# mi_statewide
# citation    793
# warning     195
# arrest        7
# Name: outcome, dtype: int64
#
#
# mt_statewide
# warning     494
# citation    486
# arrest       18
# Name: outcome, dtype: int64
#
#
# nc_statewide
# citation    664
# warning     278
# arrest       21
# Name: outcome, dtype: int64
#
#
# nh_statewide
# warning     647
# citation    279
# summons      23
# Name: outcome, dtype: int64
#
#
# nj_statewide
# citation    430
# warning     313
# arrest       18
# Name: outcome, dtype: int64
#
#
# nv_statewide
# citation    950
# arrest       34
# warning      16
# Name: outcome, dtype: int64
#
#
# oh_statewide
# warning    365
# arrest       6
# Name: outcome, dtype: int64
#
#
# ri_statewide
# citation    828
# warning      64
# arrest       31
# Name: outcome, dtype: int64
#
#
# sc_statewide
# citation    654
# arrest       21
# Name: outcome, dtype: int64
#
#
# sd_statewide
# warning     591
# citation    409
# Name: outcome, dtype: int64
#
#
# tn_statewide
# citation    1000
# Name: outcome, dtype: int64
#
#
# tx_statewide
# warning     637
# citation    363
# Name: outcome, dtype: int64
#
#
# vt_statewide
# warning     586
# citation    393
# arrest       13
# Name: outcome, dtype: int64
#
#
# wa_statewide
# citation    368
# warning     357
# Name: outcome, dtype: int64
#
#
# wi_statewide
# warning     503
# citation    471
# arrest       23
# Name: outcome, dtype: int64

# %%
for st in state_patrol:
    state_str = st
    print(state_str)
    print(sum([x for x in stpd[state_str]['search_conducted'].fillna(False).astype(int)] 
              if stpd[state_str].columns.contains('search_conducted')
              else [0 for _ in range(len(stpd[state_str]['raw_row_number']))]))
    print('\n')
# Out:
# az_statewide
# 49
#
#
# ca_statewide
# 36
#
#
# co_statewide
# 3
#
#
# ct_statewide
# 34
#
#
# fl_statewide
# 4
#
#
# ga_statewide
# 0
#
#
# ia_statewide
# 0
#
#
# il_statewide
# 44
#
#
# ma_statewide
# 19
#
#
# md_statewide
# 23
#
#
# mi_statewide
# 0
#
#
# mt_statewide
# 5
#
#
# nc_statewide
# 27
#
#
# nh_statewide
# 0
#
#
# nj_statewide
# 20
#
#
# nv_statewide
# 0
#
#
# oh_statewide
# 41
#
#
# ri_statewide
# 37
#
#
# sc_statewide
# 25
#
#
# sd_statewide
# 0
#
#
# tn_statewide
# 0
#
#
# tx_statewide
# 17
#
#
# vt_statewide
# 14
#
#
# wa_statewide
# 23
#
#
# wi_statewide
# 13

# %%
stpd['ms_statewide']['violation'].value_counts()
# Out:
# S92    354
# D36    176
# F04    122
# B26     73
# B53     60
# M14     43
# B51     37
# M81     31
# E01     28
# S93     15
# F02     13
# B55     11
# D35      6
# N50      5
# M70      4
# M84      4
# N01      4
# N60      3
# M34      2
# M02      1
# M09      1
# M08      1
# F34      1
# N84      1
# N40      1
# B08      1
# M75      1
# M40      1
# Name: violation, dtype: int64

# %%
stpd['co_statewide'].head()
# Out:
#   raw_row_number        date  time        location        county_name  \
# 0         459142  2010-09-11   NaN     1, I270, 12       Adams County
# 1         537221  2010-11-04   NaN  n/a, R2100, 10    Arapahoe County
# 2         134625  2010-03-17   NaN    174, H36, 27  Washington County
# 3  277864|277865  2010-05-29   NaN   206, H160, 23  Rio Grande County
# 4         419151  2010-08-17   NaN     87, I70, 24    Garfield County
#
#    subject_age            subject_race subject_sex officer_id_hash  \
# 0    50.993588  asian/pacific islander      female      eba6602d87
# 1    44.937329                   white        male      64148210b5
# 2    56.921165                   white      female      4b66605ae5
# 3    58.218934                   white      female      c82c53d62e
# 4          NaN                     NaN         NaN      e2677e1908
#
#   officer_sex       type                                          violation  \
# 0         NaN  vehicular      Speeding (10-19 MPH Over Prima Facie Limit *)
# 1         NaN  vehicular                                                NaN
# 2         NaN  vehicular                                                NaN
# 3         NaN  vehicular  Drove Vehicle Without Valid Driver's License (...
# 4        male  vehicular                                                NaN
#
#   arrest_made citation_issued warning_issued  outcome contraband_found  \
# 0       False           False           True  warning              NaN
# 1       False           False          False      NaN              NaN
# 2       False           False           True  warning              NaN
# 3       False           False           True  warning              NaN
# 4       False           False          False      NaN              NaN
#
#    search_conducted search_basis
# 0             False          NaN
# 1             False          NaN
# 2             False          NaN
# 3             False          NaN
# 4             False          NaN

# %%
stpd_df.iloc[10]
# Out:
# state                                  Ca
# hour                                  100
# night                                   0
# location        California Highway Patrol
# lat                                  36.1
# lng                                -119.6
# district                           Fresno
# subject_age                           200
# subject_race                     hispanic
# subject_sex                          male
# type                            vehicular
# none                                    1
# citation                                0
# arrest                                  0
# search                                  0
# Name: 10, dtype: object

# %%
stpd['az_statewide']['search_conducted'].value_counts()
# Out:
# False    951
# True      49
# Name: search_conducted, dtype: int64

# %%
stpd['az_statewide']['search_person'].value_counts()
# Out:
# True     27
# False     1
# Name: search_person, dtype: int64

# %%
for st in state_patrol:
    print(st)
    if stpd[st].columns.contains('violation'):
        print('violation')
    elif stpd[st].columns.contains('reason_for_stop'):
        print('reason_for_stop')
    else:
        print(stpd[st].columns)
    print('\n')
# Out:
# az_statewide
# violation
#
#
# ca_statewide
# violation
#
#
# co_statewide
# violation
#
#
# ct_statewide
# violation
#
#
# fl_statewide
# violation
#
#
# ga_statewide
# violation
#
#
# ia_statewide
# violation
#
#
# il_statewide
# violation
#
#
# ma_statewide
# reason_for_stop
#
#
# md_statewide
# violation
#
#
# mi_statewide
# violation
#
#
# mo_statewide
# Index(['raw_row_number', 'date', 'location', 'subject_race', 'department_name',
#        'type', 'contraband_found', 'search_conducted'],
#       dtype='object')
#
#
# ms_statewide
# violation
#
#
# mt_statewide
# violation
#
#
# nc_statewide
# reason_for_stop
#
#
# nd_statewide
# violation
#
#
# ne_statewide
# Index(['raw_row_number', 'date', 'location', 'subject_race', 'department_name',
#        'type', 'search_conducted'],
#       dtype='object')
#
#
# nh_statewide
# violation
#
#
# nj_statewide
# violation
#
#
# nv_statewide
# violation
#
#
# ny_statewide
# violation
#
#
# oh_statewide
# violation
#
#
# or_statewide
# Index(['raw_row_number', 'date', 'subject_race', 'type'], dtype='object')
#
#
# ri_statewide
# reason_for_stop
#
#
# sc_statewide
# violation
#
#
# sd_statewide
# violation
#
#
# tn_statewide
# violation
#
#
# tx_statewide
# violation
#
#
# va_statewide
# Index(['raw_row_number', 'date', 'location', 'county_name', 'subject_race',
#        'officer_id_hash', 'officer_race', 'type', 'search_conducted'],
#       dtype='object')
#
#
# vt_statewide
# reason_for_stop
#
#
# wa_statewide
# violation
#
#
# wi_statewide
# violation
#
#
# wy_statewide
# violation

# %%
stpd['az_statewide'].loc[(stpd['az_statewide']['search_conducted'] == True) & (stpd['az_statewide']['search_person'] == True)]
# Out:
#      raw_row_number        date      time                   location  \
# 34            75201  2015-04-03  16:24:00                    I17 211
# 46           111993  2012-04-30  23:45:00                    I17 200
# 115          261109  2015-08-12  14:55:00                    I17 264
# 138          310809  2013-08-31  12:25:00                  US89A 609
# 151          348422  2015-08-23  11:05:00                    I10 191
# 172          409025  2011-12-10  22:10:00                    US95 23
# 238          571321  2012-02-09  11:05:00                   SR69 294
# 257          616386  2013-02-12  07:15:00                    I10 135
# 270          646617  2015-02-03  16:26:00                  SR260 258
# 315          741237  2012-01-14  16:00:00                    I40 191
# 325          776923  2014-01-09  17:40:00                   SR101 56
# 332          790079  2015-01-04  16:45:00                  US191 117
# 426         1011280  2011-07-17  21:38:00                     I19 98
# 454         1070615  2013-07-31  16:00:00                    I40 253
# 465         1095196  2015-07-17  21:42:00                    I17 202
# 508         1202232  2011-06-24  20:00:00    ELLSWORTH/WILLIAMSFIELD
# 560         1312425  2012-03-14  23:40:00  SOUTHERN EAST OF LONGMORE
# 583         1367657  2015-03-12  12:31:00                SR260 265.5
# 590         1381619  2012-03-22  11:21:00                    I40 143
# 603         1404165  2013-03-22  16:20:00                  SR260 295
# 679         1577152  2013-05-17  23:51:00                    I10 156
# 731         1703783  2013-11-01  02:19:00                   SR101 57
# 772         1786157  2013-11-17  21:02:00              RIGGS/124THST
# 849         1929590  2011-10-27  10:09:00                    I10 257
# 882         2005944  2015-10-21  13:10:00                    I40 145
# 940         2119184  2015-09-15  21:38:00                    I10 140
# 966         2162811  2013-09-20  18:59:00                   SR67 594
#
#          county_name   subject_race subject_sex officer_id_hash       type  \
# 34   Maricopa County          white        male      6ea4dceb9e  vehicular
# 46   Maricopa County       hispanic        male      fd0bc16472  vehicular
# 115   Yavapai County       hispanic        male      2f1c70e0c0  vehicular
# 138              NaN          white        male      f901cbd776  vehicular
# 151     Pinal County       hispanic        male      db46647a7f  vehicular
# 172              NaN          white        male      5992adc99c  vehicular
# 238   Yavapai County          white        male      ca1b5975f1  vehicular
# 257  Maricopa County  other/unknown      female      d94928b907  vehicular
# 270  Coconino County       hispanic        male      cc4addbe11  vehicular
# 315  Coconino County       hispanic        male      2f4b43249c  vehicular
# 325  Maricopa County          white        male      8cb6729734  vehicular
# 332    Graham County          white        male      1c4f898e88  vehicular
# 426      Pima County          white        male      e54025cce3  vehicular
# 454    Navajo County       hispanic        male      73f35db6ee  vehicular
# 465  Maricopa County          black        male      498b24f3cb  vehicular
# 508              NaN          white        male      6aac2d884f  vehicular
# 560              NaN          black      female      f237ac9c1a  vehicular
# 583      Gila County       hispanic        male      7cc732eec8  vehicular
# 590   Yavapai County          white        male      3ce97fd0ac  vehicular
# 603    Navajo County          black        male      4e13dabdc8  vehicular
# 679  Maricopa County          white        male      8d38dee9dc  vehicular
# 731  Maricopa County  other/unknown        male      010546126b  vehicular
# 772              NaN          black      female      fd9f9fb1eb  vehicular
# 849      Pima County          white      female      2f031bdf9e  vehicular
# 882   Yavapai County          white        male      3ce97fd0ac  vehicular
# 940  Maricopa County  other/unknown        male      3e3e679401  vehicular
# 966              NaN          white        male      f901cbd776  vehicular
#
#                            violation  ...  contraband_found  contraband_drugs  \
# 34                               NaN  ...             False             False
# 46                             speed  ...             False             False
# 115                              NaN  ...              True              True
# 138                              NaN  ...             False             False
# 151                              NaN  ...              True              True
# 172                              NaN  ...             False             False
# 238           other moving violation  ...             False             False
# 257           other moving violation  ...             False             False
# 270                              NaN  ...             False             False
# 315                              NaN  ...             False             False
# 325           other moving violation  ...             False             False
# 332                            speed  ...              True              True
# 426                              NaN  ...             False             False
# 454                              NaN  ...              True              True
# 465                              NaN  ...             False             False
# 508                              NaN  ...              True              True
# 560     NA|other moving violation|NA  ...             False             False
# 583                            NA|NA  ...             False             False
# 590                              NaN  ...              True              True
# 603                            speed  ...              True              True
# 679  speed|NA|other moving violation  ...              True             False
# 731                              NaN  ...             False             False
# 772                              NaN  ...             False             False
# 849                            speed  ...              True              True
# 882                              NaN  ...              True             False
# 940                              NaN  ...             False             False
# 966                            speed  ...             False             False
#
#      contraband_other search_conducted search_person search_vehicle  \
# 34              False             True          True           True
# 46              False             True          True           True
# 115              True             True          True           True
# 138             False             True          True          False
# 151              True             True          True           True
# 172             False             True          True           True
# 238             False             True          True           True
# 257             False             True          True           True
# 270             False             True          True           True
# 315             False             True          True          False
# 325             False             True          True           True
# 332             False             True          True           True
# 426             False             True          True           True
# 454              True             True          True           True
# 465             False             True          True           True
# 508              True             True          True           True
# 560             False             True          True           True
# 583             False             True          True           True
# 590              True             True          True           True
# 603              True             True          True           True
# 679              True             True          True           True
# 731             False             True          True           True
# 772             False             True          True          False
# 849              True             True          True           True
# 882              True             True          True           True
# 940             False             True          True           True
# 966             False             True          True           True
#
#        search_basis                                    reason_for_stop  \
# 34   probable cause                                               None
# 46   probable cause                                               None
# 115  probable cause  Vehicle Type, Condition or Modification|Drivin...
# 138  probable cause                                               None
# 151  probable cause                                               None
# 172  probable cause                                               None
# 238  probable cause                                               None
# 257  probable cause                                               None
# 270         consent                                               None
# 315  probable cause                                               None
# 325  probable cause                                   Driving Behavior
# 332  probable cause                               Driver Body Language
# 426  probable cause                                   Driving Behavior
# 454  probable cause                                               None
# 465  probable cause                                   Driving Behavior
# 508  probable cause                                               None
# 560  probable cause                                   Driving Behavior
# 583  probable cause                                               None
# 590  probable cause              Driving Behavior|Driver Body Language
# 603  probable cause                                               None
# 679  probable cause                                               None
# 731  probable cause                                   Driving Behavior
# 772  probable cause                                               None
# 849  probable cause                                   Driving Behavior
# 882  probable cause              Driving Behavior|Driver Body Language
# 940  probable cause                                               None
# 966  probable cause                                               None
#
#     vehicle_type vehicle_year
# 34            VN       1996.0
# 46          2DSD       1990.0
# 115         12PU       2011.0
# 138         2DSW       1997.0
# 151         4DSD       2014.0
# 172         4DSW       1999.0
# 238         4DSD       2008.0
# 257         4DSD       2009.0
# 270         4DSW       2001.0
# 315         4DSD       2002.0
# 325         12PU       2011.0
# 332         4DSD       1987.0
# 426         12PU       1998.0
# 454         2DSD       1998.0
# 465         4DSD       2008.0
# 508         4DSD       2004.0
# 560         4DSD       2002.0
# 583         1TPU       2000.0
# 590         4DSD       2010.0
# 603         4DSD       2010.0
# 679           TK       2009.0
# 731         12PU       2003.0
# 772         4DSD       2005.0
# 849         4DSW       2003.0
# 882         4DSD       2014.0
# 940         12PU       2006.0
# 966         4DSD       2004.0
#
# [27 rows x 24 columns]

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
